# %% [markdown]
# ### Group ID: 134
# ### Group Members Name with Student ID:
#
# | Student Name       | Student ID    | Contribution |
# |--------------------|---------------|--------------|
# | Chakshu            | 2023aa05280   | 100%         |
# | Gali Jahnavi       | 2023aa05684   | 100%         |
# | Aashaank Pratap    | 2023aa05023   | 100%         |
# | Shivam Sahil       | 2023aa05663   | 100%         |

# %% [markdown]
# # Problem Statement
#
# The objective of the problem is to implement an Actor-Critic reinforcement learning algorithm to optimize energy consumption in a building. The agent should learn to adjust the temperature settings dynamically to minimize energy usage while maintaining comfortable indoor conditions.

# %% [markdown]
# #### Dataset Details
# Dataset: https://archive.ics.uci.edu/dataset/374/appliances+energy+prediction
#
# This dataset contains energy consumption data for a residential building, along with various environmental and operational factors.
#
# Data Dictionary:
# * Appliances:       Energy use in Wh
# * lights:           Energy use of light fixtures in the house in Wh
# * T1 - T9:          Temperatures in various rooms and outside
# * RH_1 to RH_9:     Humidity measurements in various rooms and outside
# * Visibility:       Visibility in km
# * Tdewpoint:       Dew point temperature
# * Pressure_mm_hgg:  Pressure in mm Hg
# * Windspeed:        Wind speed in m/s

# %% [markdown]
# #### Environment Details
# **State Space:**
# The state space consists of various features from the dataset that impact energy consumption and comfort levels.
#
# * Current Temperature (T1 to T9): Temperatures in various rooms and outside.
# * Current Humidity (RH_1 to RH_9): Humidity measurements in different locations.
# * Visibility (Visibility): Visibility in meters.
# * Dew Point (Tdewpoint): Dew point temperature.
# * Pressure (Press_mm_hg): Atmospheric pressure in mm Hg.
# * Windspeed (Windspeed): Wind speed in m/s.
#
# Total State Vector Dimension: Number of features = 9 (temperature) + 9 (humidity) + 1 (visibility) + 1 (dew point) + 1 (pressure) + 1 (windspeed) = 22 features
#
# **Target Variable:** Appliances (energy consumption in Wh).
#
# **Action Space:**
# The action space consists of discrete temperature adjustments:
# * Action 0: Decrease temperature by 1°C
# * Action 1: Maintain current temperature
# * Action 2: Increase temperature by 1°C
#
#
# - If the action is to decrease the temperature by 1°C, you'll adjust each temperature feature (T1 to T9) down by 1°C.
# - If the action is to increase the temperature by 1°C, you'll adjust each temperature feature (T1 to T9) up by 1°C.
# - Other features remain unchanged.
#
# **Policy (Actor):** A neural network that outputs a probability distribution over possible temperature adjustments.
#
# **Value function (Critic):** A neural network that estimates the expected cumulative reward (energy savings) from a given state.
#
# **Reward function:**
# The reward function should reflect the overall comfort and energy efficiency based on all temperature readings. i.e., balance between minimising temperature deviations and minimizing energy consumption.
#
# * Calculate the penalty based on the deviation of each temperature from the target temperature and then aggregate these penalties.
# * Measure the change in energy consumption before and after applying the RL action.
# * Combine the comfort penalty and energy savings to get the final reward.
#
# *Example:*
#
# Target temperature=22°C
#
# Initial Temperatures: T1=23, T2=22, T3=21, T4=23, T5=22, T6=21, T7=24, T8=22, T9=23
#
# Action Taken: Decrease temperature by 1°C for each room
#
# Resulting Temperatures: T1 = 22, T2 = 21, T3 = 20, T4 = 22, T5 = 21, T6 = 20, T7 = 23, T8 = 21, T9 = 22
#
# Energy Consumption: 50 Wh (before RL adjustment) and 48 Wh (after RL adjustment)
# * Energy Before (50 Wh): Use the energy consumption from the dataset at the current time step.
# * Energy After (48 Wh): Use the energy consumption from the dataset at the next time step (if available).
#
# Consider only temperature features for deviation calculation.
#
# Deviation = abs (Ti− Ttarget )
#
# Deviations=[ abs(22−22), abs(21−22), abs(20−22), abs(22−22),  abs(21−22), abs(20−22), abs(23−22), abs(21−22), abs(22−22) ]
#
# Deviations = [0, 1, 2, 0, 1, 2, 1, 1, 0], Sum of deviations = 8
#
# Energy Savings = Energy Before−Energy After = 50 – 48 = 2Wh
#
# Reward= −Sum of Deviations + Energy Savings = -8+6 = -2

# %% [markdown]
# #### Expected Outcomes
# 1. Pre-process the dataset to handle any missing values and create training and testing sets.
# 2. Implement the Actor-Critic algorithm using TensorFlow.
# 3. Train the model over 500 episodes to minimize energy consumption while maintaining an indoor temperature of 22°C.
# 4. Plot the total reward obtained in each episode to evaluate the learning progress.
# 5. Evaluate the performance of the model on test set to measure its performance
# 6. Provide graphs showing the convergence of the Actor and Critic losses.
# 7. Plot the learned policy by showing the action probabilities across different state values (e.g., temperature settings).
# 8. Provide an analysis on a comparison of the energy consumption before and after applying the reinforcement learning algorithm.

# %%
# Necessary Imports
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
import warnings
import matplotlib.pyplot as plt

# %%
# file_path = 'https://raw.githubusercontent.com/sedhha/bits-ai-ml-practice-problems/main/2825/assignment_2/dataset/energydata_complete.csv'
# Load the dataset
file_path = r'dataset/energydata_complete.csv'
data = pd.read_csv(file_path)
data['date'] = pd.to_datetime(data['date'])

# Set 'date' as the index for time-based operations
data.set_index('date', inplace=True)

# Extract temporal features
data['hour'] = data.index.hour
data['day_of_week'] = data.index.dayofweek
data['month'] = data.index.month

# Handle missing values using time-aware methods
numeric_columns = data.select_dtypes(include=[np.number]).columns
data[numeric_columns] = data[numeric_columns].interpolate(method='time')
data[numeric_columns] = data[numeric_columns].fillna(method='bfill')

# Define features and target
features = ['T1', 'T2', 'T3', 'T4', 'T5', 'T6', 'T7', 'T8', 'T9',
            'RH_1', 'RH_2', 'RH_3', 'RH_4', 'RH_5', 'RH_6', 'RH_7', 'RH_8', 'RH_9',
            'Visibility', 'Tdewpoint', 'Press_mm_hg', 'Windspeed',
            'hour', 'day_of_week', 'month']
target = 'Appliances'

X = data[features]
y = data[target]

# Split the data without shuffling
split_index = int(len(X) * 0.8)
X_train, X_test = X[:split_index], X[split_index:]
y_train, y_test = y[:split_index], y[split_index:]
data_train, data_test = data.iloc[:split_index], data.iloc[split_index:]

# Reset indices to maintain consistency
X_train.reset_index(drop=True, inplace=True)
X_test.reset_index(drop=True, inplace=True)
y_train.reset_index(drop=True, inplace=True)
y_test.reset_index(drop=True, inplace=True)
data_train.reset_index(drop=True, inplace=True)
data_test.reset_index(drop=True, inplace=True)

# Fit scaler on training data only
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)

# Transform test data using the same scaler
X_test_scaled = scaler.transform(X_test)

# Convert scaled arrays back to DataFrames and set columns
X_train = pd.DataFrame(X_train_scaled, columns=features)
X_test = pd.DataFrame(X_test_scaled, columns=features)

print("Data preprocessing completed.")
print(f"Training set shape: {X_train.shape}")
print(f"Testing set shape: {X_test.shape}")

print(f"Length of X_train: {len(X_train)}")
print(f"Length of data_train: {len(data_train)}")
print(f"Length of y_train: {len(y_train)}")
# Out:
# Data preprocessing completed.
# Training set shape: (15788, 25)
# Testing set shape: (3947, 25)
# Length of X_train: 15788
# Length of data_train: 15788
# Length of y_train: 15788
# /var/folders/sb/2zyx_gr14m9cc4dd9p3l0d840000gp/T/ipykernel_15115/3041516445.py:18: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data[numeric_columns] = data[numeric_columns].fillna(method='bfill')

# %% [markdown]
# #### Defining Actor Critic Model using tensorflow (1 M)

# %%
# Define Actor and Critic models
class Actor(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(Actor, self).__init__()
        self.fc1 = nn.Linear(state_dim, 128)
        self.dropout1 = nn.Dropout(p=0.2)
        self.fc2 = nn.Linear(128, 64)
        self.dropout2 = nn.Dropout(p=0.2)
        self.fc3 = nn.Linear(64, action_dim)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = self.dropout1(x)
        x = torch.relu(self.fc2(x))
        x = self.dropout2(x)
        return torch.softmax(self.fc3(x), dim=-1)


class Critic(nn.Module):
    def __init__(self, state_dim):
        super(Critic, self).__init__()
        self.fc1 = nn.Linear(state_dim, 64)
        self.fc2 = nn.Linear(64, 64)
        self.fc3 = nn.Linear(64, 1)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.fc3(x)

# %% [markdown]
# ### Reward Function (0.5 M)

# %%
def calculate_reward(new_temps, energy_before, energy_after, action):
    target_temp = 22.0

    # Calculate deviations from target temperature
    deviations = [abs(temp - target_temp) for temp in new_temps]
    total_deviation = sum(deviations)

    # Calculate energy saved
    energy_saved = energy_before - energy_after  # Positive if energy consumption decreased

    # Scaling factors
    deviation_penalty_weight = 1.0
    energy_savings_scaling_factor = 3.0

    # Scale energy savings
    energy_savings_scaled = energy_saved * energy_savings_scaling_factor

    # Total reward
    reward = - (deviation_penalty_weight * total_deviation) + energy_savings_scaled

    return reward

# %% [markdown]
# #### Environment Simulation (0.5 M)

# %%
# Environment simulation
def simulate_environment(state, action, scaler, data, current_index):
    orig_state = scaler.inverse_transform(state.reshape(1, -1)).flatten()

    # Separate temperature and other features
    temps = orig_state[:9]
    other_features = orig_state[9:]

    # Apply action to temperatures
    temp_adjustment = [-1.0, 0.0, 1.0][action]  # Actions: Decrease, Maintain, Increase
    new_temps = temps + temp_adjustment
    new_temps = np.clip(new_temps, 10, 35)

    # Ensure current_index is valid
    if current_index >= len(data):
        current_index = len(data) - 1

    # Simulate energy consumption after action
    energy_before = data.iloc[current_index]['Appliances']

    # Energy change is symmetric for increase and decrease
    energy_sensitivity = 10  # Adjust this value as needed
    energy_change = temp_adjustment * energy_sensitivity

    energy_after = energy_before + energy_change

    # Construct next state
    next_state = np.concatenate([new_temps, other_features])
    next_state_scaled = scaler.transform(next_state.reshape(1, -1)).flatten()

    # Calculate reward
    reward = calculate_reward(new_temps, energy_before, energy_after, action)

    return next_state_scaled, reward

# %% [markdown]
# #### Implementation of Training Function (2 M)

# %%
# Training function
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

def train_function(X_train, state_dim, action_dim, scaler, episodes=500, steps = 250):
    warnings.filterwarnings("ignore", category=UserWarning, message="X does not have valid feature names, but StandardScaler was fitted with feature names")
    
    # Epsilon-greedy parameters
    epsilon_start = 1.0
    epsilon_end = 0.1
    epsilon_decay = episodes / 2

    # Entropy regularization coefficient
    entropy_coefficient = 0.001
    
    actor = Actor(state_dim, action_dim).to(device)
    critic = Critic(state_dim).to(device)
    actor_optimizer = optim.Adam(actor.parameters(), lr=0.0001)
    critic_optimizer = optim.Adam(critic.parameters(), lr=0.0005)

    actor_losses = []
    critic_losses = []
    episode_rewards = []
    for episode in range(episodes):
        # Start from a random state index
        state_index = np.random.randint(0, len(X_train) - 1)
        state = torch.FloatTensor(X_train.iloc[state_index].to_numpy()).to(device)
        total_reward = 0
        epsilon = epsilon_end + (epsilon_start - epsilon_end) * np.exp(-1. * episode / epsilon_decay)
        for step in range(steps):  # Limit steps per episode for faster training
            action_probs = actor(state)
            m = torch.distributions.Categorical(action_probs)

            # Epsilon-greedy action selection
            if np.random.rand() < epsilon:
                # Random action (exploration)
                action = torch.tensor([np.random.choice(action_dim)]).to(device)
            else:
                # Action according to policy (exploitation)
                action = m.sample()

            # Calculate entropy of the action distribution
            entropy = m.entropy()

            # Simulate environment
            current_index = state_index
            next_state, reward = simulate_environment(
                state.cpu().numpy(), action.item(), scaler, data_train, current_index)
            next_state = torch.FloatTensor(next_state).to(device)
            reward = torch.tensor([reward], dtype=torch.float32, device=device)

            # Compute critic values
            critic_value = critic(state)
            critic_value_next = critic(next_state)

            # Compute TD error (delta)
            delta = reward + 0.99 * critic_value_next - critic_value

            # Critic loss
            critic_loss = delta.pow(2).mean()

            # Actor loss with entropy regularization
            actor_loss = - (m.log_prob(action) * delta.detach() + entropy_coefficient * entropy)

            # Update Critic
            critic_optimizer.zero_grad()
            critic_loss.backward()
            torch.nn.utils.clip_grad_norm_(critic.parameters(), max_norm=1.0)
            critic_optimizer.step()

            # Update Actor
            actor_optimizer.zero_grad()
            actor_loss.backward()
            torch.nn.utils.clip_grad_norm_(actor.parameters(), max_norm=1.0)
            actor_optimizer.step()

            # Move to next state and index
            state = next_state
            state_index = (state_index + 1) % len(X_train)

            total_reward += reward.item()
            actor_losses.append(actor_loss.item())
            critic_losses.append(critic_loss.item())
               
        print(f"Episode {episode + 1}, Step {step + 1}, Total Reward: {total_reward}, Actor Loss: {actor_loss.item()}, Critic Loss: {critic_loss.item()}")
        episode_rewards.append(total_reward)
    print("Training complete!")

    return actor, episode_rewards, actor_losses, critic_losses
# Out:
# Using device: cpu

# %% [markdown]
# #### Evaluate the performance of the model on test set (0.5 M)

# %%
def evaluate_model(X_test, actor, scaler, data):
    total_reward = 0
    time_factor = 0
    state = torch.FloatTensor(X_test.iloc[0].values).to(device) # Start with the first state

    for step in range(len(X_test) - 1):
        # Predict action
        with torch.no_grad():
            action_probs = actor(state)
        action = torch.argmax(action_probs).item()

        # Simulate environment
        next_state, reward = simulate_environment(state.numpy(), action, scaler, data, step)

        total_reward += reward
        
        # Update state for the next iteration
        state = torch.FloatTensor(next_state)
        time_factor = (time_factor + 1) % 360  # Update time factor

    print(f"Total reward on test set: {total_reward}")
    return total_reward

# %% [markdown]
# ### Plot the convergence of Actor and Critic losses (1 M)

# %%
# Plots

# Plot the convergence of Actor and Critic losses
def plot_losses(actor_losses, critic_losses):
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(actor_losses)
    plt.title('Actor Loss')
    plt.xlabel('Training Step')
    plt.ylabel('Loss')

    plt.subplot(1, 2, 2)
    plt.plot(critic_losses)
    plt.title('Critic Loss')
    plt.xlabel('Training Step')
    plt.ylabel('Loss')

    plt.tight_layout()
    plt.show()

# Plot the learned policy
def plot_learned_policy(X_train, actor):
    states = torch.FloatTensor(X_train.iloc[:100].values).to(device)  # Use a subset of states for visualization
    with torch.no_grad():
        action_probs = actor(states)

    action_probs = action_probs.numpy()

    plt.figure(figsize=(10, 6))
    plt.plot(action_probs[:, 0], label='Decrease Temp')
    plt.plot(action_probs[:, 1], label='Maintain Temp')
    plt.plot(action_probs[:, 2], label='Increase Temp')
    plt.title('Action Probabilities Across Different States')
    plt.xlabel('State Index')
    plt.ylabel('Action Probability')
    plt.legend()
    plt.show()

def plot_episode_rewards(episode_rewards):
    plt.figure(figsize=(10, 6))
    plt.plot(episode_rewards)
    plt.title('Total Reward per Episode')
    plt.xlabel('Episode')
    plt.ylabel('Total Reward')
    plt.show()

# Conclusion and analysis
def analyze_results(y_train, y_test, episode_rewards):
    print("Analysis of energy consumption before and after applying RL:")
    print(f"Average energy consumption before RL: {y_train.mean():.2f} Wh")
    print(f"Average energy consumption after RL (estimated): {y_test.mean() - episode_rewards[-1]/len(y_test):.2f} Wh")
    print(f"Estimated energy savings: {(y_train.mean() - (y_test.mean() - episode_rewards[-1]/len(y_test))) / y_train.mean() * 100:.2f}%")

# %% [markdown]
# ### Plot the learned policy - by showing the action probabilities across different state values (1 M)

# %%
# Initiate training
def run_rl_process(X_train, y_train, X_test, y_test, scaler, data_test, episodes=500, action_dim = 3, steps = 250):
    # Train the model
    state_dim = X_train.shape[1]
    actor, episode_rewards, actor_losses, critic_losses = train_function(
        X_train, state_dim, action_dim, scaler, episodes=episodes, steps = steps)

    # Evaluate the model
    evaluate_model(X_test, actor, scaler, data_test)

    # Plot episode rewards
    plot_episode_rewards(episode_rewards)

    # Plot losses
    plot_losses(actor_losses, critic_losses)

    # Plot learned policy
    plot_learned_policy(X_train, actor)

    # Analyze results
    analyze_results(y_train, y_test, episode_rewards)

    print("Reinforcement learning process completed.")

# %%
# Run the entire process
run_rl_process(X_train, y_train, X_test, y_test, scaler, data_train, data_test, episodes=5000)
# Out:
# Episode 1, Step 250, Total Reward: -10042.681448936462, Actor Loss: -3.72652006149292, Critic Loss: 220.9320068359375
# Episode 2, Step 250, Total Reward: -15170.366621017456, Actor Loss: -139.9241485595703, Critic Loss: 1283.41455078125
# Episode 3, Step 250, Total Reward: -18225.82248878479, Actor Loss: -283.3262939453125, Critic Loss: 10755.2529296875
# Episode 4, Step 250, Total Reward: -5709.093790054321, Actor Loss: -78.62136840820312, Critic Loss: 3545.7666015625
# Episode 5, Step 250, Total Reward: -14013.636238098145, Actor Loss: -533.9586181640625, Critic Loss: 1877.3026123046875
# Episode 6, Step 250, Total Reward: -11287.02017211914, Actor Loss: -12.922943115234375, Critic Loss: 1129.5880126953125
# Episode 7, Step 250, Total Reward: -15870.47403049469, Actor Loss: -6.552319064212497e-06, Critic Loss: 3021.0234375
# Episode 8, Step 250, Total Reward: -8444.627598762512, Actor Loss: -609.4591674804688, Critic Loss: 13068.896484375
# Episode 9, Step 250, Total Reward: -14393.313292503357, Actor Loss: -1653.8992919921875, Critic Loss: 10762.4609375
# Episode 10, Step 250, Total Reward: -16737.716609954834, Actor Loss: -2.511896848678589, Critic Loss: 1822.17578125
# Episode 11, Step 250, Total Reward: -17821.144912719727, Actor Loss: 0.10621828585863113, Critic Loss: 825.6011962890625
# Episode 12, Step 250, Total Reward: -15971.57179927826, Actor Loss: -2403.310546875, Critic Loss: 22725.48828125
# Episode 13, Step 250, Total Reward: -14997.460845947266, Actor Loss: 6.9934983253479, Critic Loss: 1.3997385501861572
# Episode 14, Step 250, Total Reward: -9567.73342514038, Actor Loss: -624.5962524414062, Critic Loss: 1534.9427490234375
# Episode 15, Step 250, Total Reward: -12307.186541557312, Actor Loss: -1287.4779052734375, Critic Loss: 6521.88330078125
# Episode 16, Step 250, Total Reward: -8305.673069000244, Actor Loss: -1793.4580078125, Critic Loss: 12655.3984375
# Episode 17, Step 250, Total Reward: -18302.77307701111, Actor Loss: -930.3759155273438, Critic Loss: 3405.731201171875
# Episode 18, Step 250, Total Reward: -6872.70631313324, Actor Loss: 148.19378662109375, Critic Loss: 517.9180297851562
# Episode 19, Step 250, Total Reward: -15788.106486320496, Actor Loss: 4.4497983253677376e-06, Critic Loss: 1393.4254150390625
# Episode 20, Step 250, Total Reward: -10916.760204315186, Actor Loss: -3284.843505859375, Critic Loss: 42454.41015625
# Episode 21, Step 250, Total Reward: -9455.510127067566, Actor Loss: 128.2046356201172, Critic Loss: 64.66970825195312
# Episode 22, Step 250, Total Reward: -15739.233421325684, Actor Loss: -5.762295813838136e-07, Critic Loss: 23.35560417175293
# Episode 23, Step 250, Total Reward: -9143.13698387146, Actor Loss: -20.819332122802734, Critic Loss: 1.7053961753845215
# Episode 24, Step 250, Total Reward: -20205.090027809143, Actor Loss: -22.271076202392578, Critic Loss: 1.9515326023101807
# Episode 25, Step 250, Total Reward: -13938.359861373901, Actor Loss: 3.5745695186051307e-06, Critic Loss: 899.2091674804688
# Episode 26, Step 250, Total Reward: -13221.423363685608, Actor Loss: 1.5108934121599304e-06, Critic Loss: 160.66305541992188
# Episode 27, Step 250, Total Reward: -16528.103702545166, Actor Loss: -548.875732421875, Critic Loss: 1185.336181640625
# Episode 28, Step 250, Total Reward: -12286.410174369812, Actor Loss: 3.7974086808389984e-06, Critic Loss: 1014.8175659179688
# Episode 29, Step 250, Total Reward: -6099.364243507385, Actor Loss: 19.16315269470215, Critic Loss: 93.59712219238281
# Episode 30, Step 250, Total Reward: -12816.13572883606, Actor Loss: 0.12593260407447815, Critic Loss: 771.2282104492188
# Episode 31, Step 250, Total Reward: -12980.540641784668, Actor Loss: 1.9330484235524636e-07, Critic Loss: 2.6326963901519775
# Episode 32, Step 250, Total Reward: -9183.28012084961, Actor Loss: 4.7638163566589355, Critic Loss: 187.72210693359375
# Episode 33, Step 250, Total Reward: -10900.49833202362, Actor Loss: -443.2652282714844, Critic Loss: 773.073486328125
# Episode 34, Step 250, Total Reward: -10684.975359916687, Actor Loss: 0.0004977828939445317, Critic Loss: 227.59288024902344
# Episode 35, Step 250, Total Reward: -8198.92695236206, Actor Loss: -1.612151322660793e-06, Critic Loss: 182.86355590820312
# Episode 36, Step 250, Total Reward: -19983.220001220703, Actor Loss: 1.7085659465010394e-06, Critic Loss: 205.44911193847656
# Episode 37, Step 250, Total Reward: -6983.820751190186, Actor Loss: 49.22545623779297, Critic Loss: 331.353759765625
# Episode 38, Step 250, Total Reward: -11342.345348358154, Actor Loss: 0.5451105833053589, Critic Loss: 790.8233642578125
# Episode 39, Step 250, Total Reward: -8155.360220909119, Actor Loss: -17.4642276763916, Critic Loss: 1.2000303268432617
# Episode 40, Step 250, Total Reward: -8645.71366405487, Actor Loss: -2413.3017578125, Critic Loss: 22914.833984375
# Episode 41, Step 250, Total Reward: -11669.557563781738, Actor Loss: -2.887306436605286e-06, Critic Loss: 586.5833129882812
# Episode 42, Step 250, Total Reward: -16569.396589279175, Actor Loss: -897.0783081054688, Critic Loss: 3166.315185546875
# Episode 43, Step 250, Total Reward: -17165.629972457886, Actor Loss: 341.94390869140625, Critic Loss: 460.04803466796875
# Episode 44, Step 250, Total Reward: -7937.920188903809, Actor Loss: -1702.908203125, Critic Loss: 11409.7451171875
# Episode 45, Step 250, Total Reward: -13478.586532592773, Actor Loss: 1.9875755310058594, Critic Loss: 111.06669616699219
# Episode 46, Step 250, Total Reward: -10765.88954257965, Actor Loss: -820.6903076171875, Critic Loss: 2650.03759765625
# Episode 47, Step 250, Total Reward: -14288.33020401001, Actor Loss: 4.140715645917226e-06, Critic Loss: 1206.57861328125
# Episode 48, Step 250, Total Reward: -6795.527173995972, Actor Loss: 1.8165702819824219, Critic Loss: 5.023026466369629
# Episode 49, Step 250, Total Reward: -13758.269941329956, Actor Loss: 2.758555183390854e-06, Critic Loss: 535.5563354492188
# Episode 50, Step 250, Total Reward: -20063.69002723694, Actor Loss: -635.1265258789062, Critic Loss: 1587.1353759765625
# Episode 51, Step 250, Total Reward: -18641.390293121338, Actor Loss: -497.42108154296875, Critic Loss: 973.5131225585938
# Episode 52, Step 250, Total Reward: -12981.43304157257, Actor Loss: 136.71044921875, Critic Loss: 180.55328369140625
# Episode 53, Step 250, Total Reward: -15691.584434509277, Actor Loss: -699.402099609375, Critic Loss: 1924.6300048828125
# Episode 54, Step 250, Total Reward: -15377.635195732117, Actor Loss: 1.3651032531925011e-05, Critic Loss: 13113.4931640625
# Episode 55, Step 250, Total Reward: -7046.190202713013, Actor Loss: 27.405845642089844, Critic Loss: 122.2708969116211
# Episode 56, Step 250, Total Reward: -8894.935020446777, Actor Loss: 79.79532623291016, Critic Loss: 315.010498046875
# Episode 57, Step 250, Total Reward: -14152.003472328186, Actor Loss: -1361.9451904296875, Critic Loss: 7298.14794921875
# Episode 58, Step 250, Total Reward: -19034.60013771057, Actor Loss: 98.81636047363281, Critic Loss: 221.41091918945312
# Episode 59, Step 250, Total Reward: -10055.340019226074, Actor Loss: -3.950382051698398e-06, Critic Loss: 1098.074462890625
# Episode 60, Step 250, Total Reward: -9602.833281517029, Actor Loss: -384.8824768066406, Critic Loss: 582.8405151367188
# Episode 61, Step 250, Total Reward: -11864.32607460022, Actor Loss: 46.307350158691406, Critic Loss: 52.07863235473633
# Episode 62, Step 250, Total Reward: -9769.063432693481, Actor Loss: 21.130552291870117, Critic Loss: 782.6607055664062
# Episode 63, Step 250, Total Reward: -8328.213632583618, Actor Loss: -528.2744140625, Critic Loss: 1098.0260009765625
# Episode 64, Step 250, Total Reward: -14207.549947738647, Actor Loss: -910.0665283203125, Critic Loss: 4682.9560546875
# Episode 65, Step 250, Total Reward: -7605.060366630554, Actor Loss: 0.016671760007739067, Critic Loss: 27.943199157714844
# Episode 66, Step 250, Total Reward: -7412.5601596832275, Actor Loss: 60.845340728759766, Critic Loss: 69.22760009765625
# Episode 67, Step 250, Total Reward: -15011.66633605957, Actor Loss: -15.378019332885742, Critic Loss: 0.9304524064064026
# Episode 68, Step 250, Total Reward: -7700.400367736816, Actor Loss: -3.828266926575452e-06, Critic Loss: 1031.2314453125
# Episode 69, Step 250, Total Reward: -7884.7002630233765, Actor Loss: 22.29421615600586, Critic Loss: 158.00048828125
# Episode 70, Step 250, Total Reward: -19107.68155670166, Actor Loss: -239.82861328125, Critic Loss: 226.30560302734375
# Episode 71, Step 250, Total Reward: -12188.083106994629, Actor Loss: 190.14874267578125, Critic Loss: 142.2592010498047
# Episode 72, Step 250, Total Reward: -16366.207046508789, Actor Loss: -710.9423828125, Critic Loss: 1988.6678466796875
# Episode 73, Step 250, Total Reward: -8960.200462341309, Actor Loss: 3.2609851360321045, Critic Loss: 307.0879821777344
# Episode 74, Step 250, Total Reward: -9841.380088806152, Actor Loss: -1011.360595703125, Critic Loss: 4024.4404296875
# Episode 75, Step 250, Total Reward: -6883.320633888245, Actor Loss: -28.384803771972656, Critic Loss: 9.10283088684082
# Episode 76, Step 250, Total Reward: -9067.270002365112, Actor Loss: 17.30916976928711, Critic Loss: 22.797361373901367
# Episode 77, Step 250, Total Reward: -9408.824437141418, Actor Loss: 1.3616198657473433e-06, Critic Loss: 130.48712158203125
# Episode 78, Step 250, Total Reward: -6904.520450592041, Actor Loss: -155.4999542236328, Critic Loss: 195.37841796875
# Episode 79, Step 250, Total Reward: -10467.553379058838, Actor Loss: -1222.2896728515625, Critic Loss: 5878.16455078125
# Episode 80, Step 250, Total Reward: -15049.590193748474, Actor Loss: -386.8519287109375, Critic Loss: 588.820556640625
# Episode 81, Step 250, Total Reward: -19602.119659423828, Actor Loss: -694.5446166992188, Critic Loss: 1897.9892578125
# Episode 82, Step 250, Total Reward: -8262.679810523987, Actor Loss: -3.0489493383356603e-06, Critic Loss: 654.1030883789062
# Episode 83, Step 250, Total Reward: -12668.8392868042, Actor Loss: 0.7433071732521057, Critic Loss: 1493.4375
# Episode 84, Step 250, Total Reward: -13134.947713851929, Actor Loss: 63.05807876586914, Critic Loss: 40.56595230102539
# Episode 85, Step 250, Total Reward: -8303.761989593506, Actor Loss: -253.93385314941406, Critic Loss: 253.70828247070312
# Episode 86, Step 250, Total Reward: -10152.045712471008, Actor Loss: -2.612770003906917e-06, Critic Loss: 480.3331298828125
# Episode 87, Step 250, Total Reward: -7907.188858032227, Actor Loss: -381.0408935546875, Critic Loss: 571.263671875
# Episode 88, Step 250, Total Reward: -11610.239818572998, Actor Loss: -2.5829676815192215e-06, Critic Loss: 469.4373779296875
# Episode 89, Step 250, Total Reward: -19454.13482284546, Actor Loss: -215.57249450683594, Critic Loss: 182.84375
# Episode 90, Step 250, Total Reward: -7027.333634376526, Actor Loss: -511.4679870605469, Critic Loss: 1029.2723388671875
# Episode 91, Step 250, Total Reward: -8748.517042160034, Actor Loss: -5.535493073693942e-06, Critic Loss: 2156.1240234375
# Episode 92, Step 250, Total Reward: -8984.020038604736, Actor Loss: -3.36673903465271, Critic Loss: 0.04459768533706665
# Episode 93, Step 250, Total Reward: -13467.620866775513, Actor Loss: -1.9514727682690136e-06, Critic Loss: 267.9487609863281
# Episode 94, Step 250, Total Reward: -15452.719972610474, Actor Loss: 22.233835220336914, Critic Loss: 74.17179107666016
# Episode 95, Step 250, Total Reward: -14957.004350662231, Actor Loss: 180.75843811035156, Critic Loss: 3141.306884765625
# Episode 96, Step 250, Total Reward: -6816.100234985352, Actor Loss: -177.3512420654297, Critic Loss: 123.7547607421875
# Episode 97, Step 250, Total Reward: -6237.300008773804, Actor Loss: -99.9679946899414, Critic Loss: 93.74362182617188
# Episode 98, Step 250, Total Reward: -7656.440960884094, Actor Loss: -157.9759521484375, Critic Loss: 98.19184112548828
# Episode 99, Step 250, Total Reward: -6892.900502204895, Actor Loss: 32.31290054321289, Critic Loss: 104.66249084472656
# Episode 100, Step 250, Total Reward: -17640.1596698761, Actor Loss: -6.168443178466987e-06, Critic Loss: 2677.405517578125
# Episode 101, Step 250, Total Reward: -8117.513139724731, Actor Loss: -634.5894165039062, Critic Loss: 1584.4520263671875
# Episode 102, Step 250, Total Reward: -14853.677293777466, Actor Loss: 51.326759338378906, Critic Loss: 394.88946533203125
# Episode 103, Step 250, Total Reward: -10277.951700210571, Actor Loss: 92.85356903076172, Critic Loss: 267.2857666015625
# Episode 104, Step 250, Total Reward: -13263.556652069092, Actor Loss: 9.728217946758377e-07, Critic Loss: 66.612060546875
# Episode 105, Step 250, Total Reward: -15923.467071533203, Actor Loss: 91.73876953125, Critic Loss: 33.11305618286133
# Episode 106, Step 250, Total Reward: -7618.949266433716, Actor Loss: -0.11347796022891998, Critic Loss: 0.0009164810180664062
# Episode 107, Step 250, Total Reward: -10668.489559173584, Actor Loss: -623.1502685546875, Critic Loss: 1527.8441162109375
# Episode 108, Step 250, Total Reward: -9996.449954986572, Actor Loss: 3.076850771321915e-05, Critic Loss: 126.24409484863281
# Episode 109, Step 250, Total Reward: -7474.293469429016, Actor Loss: -2.2157646526466124e-06, Critic Loss: 345.4461364746094
# Episode 110, Step 250, Total Reward: -8676.033487319946, Actor Loss: 12.777997970581055, Critic Loss: 618.9235229492188
# Episode 111, Step 250, Total Reward: -10469.626625061035, Actor Loss: -1241.310791015625, Critic Loss: 6062.53857421875
# Episode 112, Step 250, Total Reward: -11726.540472984314, Actor Loss: 0.0013845372013747692, Critic Loss: 937.2626953125
# Episode 113, Step 250, Total Reward: -19190.18984413147, Actor Loss: -331.4817199707031, Critic Loss: 432.3272399902344
# Episode 114, Step 250, Total Reward: -15450.899938583374, Actor Loss: -3.7590532302856445, Critic Loss: 1.3539049625396729
# Episode 115, Step 250, Total Reward: -16956.154224395752, Actor Loss: 38.9000358581543, Critic Loss: 928.9547729492188
# Episode 116, Step 250, Total Reward: -10357.707094192505, Actor Loss: -4356.96484375, Critic Loss: 74689.84375
# Episode 117, Step 250, Total Reward: -7624.760343551636, Actor Loss: 0.06646642833948135, Critic Loss: 24.1168270111084
# Episode 118, Step 250, Total Reward: -14710.917171478271, Actor Loss: 6.481202581198886e-05, Critic Loss: 473.5511474609375
# Episode 119, Step 250, Total Reward: -9618.240145683289, Actor Loss: 295.2834777832031, Critic Loss: 1117.1849365234375
# Episode 120, Step 250, Total Reward: -8134.023826599121, Actor Loss: 83.31683349609375, Critic Loss: 521.7254028320312
# Episode 121, Step 250, Total Reward: -7840.4200620651245, Actor Loss: 6.974016741878586e-06, Critic Loss: 70.10382843017578
# Episode 122, Step 250, Total Reward: -12727.124691009521, Actor Loss: 86.64000701904297, Critic Loss: 29.53455352783203
# Episode 123, Step 250, Total Reward: -10136.284507751465, Actor Loss: 1.7872456312179565, Critic Loss: 449.0032653808594
# Episode 124, Step 250, Total Reward: -16010.803224563599, Actor Loss: 70.33798217773438, Critic Loss: 91.24073791503906
# Episode 125, Step 250, Total Reward: -9636.760067939758, Actor Loss: -485.56939697265625, Critic Loss: 927.6753540039062
# Episode 126, Step 250, Total Reward: -8436.227235794067, Actor Loss: -757.9599609375, Critic Loss: 2260.403564453125
# Episode 127, Step 250, Total Reward: -12716.679954528809, Actor Loss: -177.8572235107422, Critic Loss: 124.4619140625
# Episode 128, Step 250, Total Reward: -10818.019863128662, Actor Loss: -884.1484375, Critic Loss: 3075.698974609375
# Episode 129, Step 250, Total Reward: -11415.76880645752, Actor Loss: 11.471220970153809, Critic Loss: 1.0122442245483398
# Episode 130, Step 250, Total Reward: -12730.874958992004, Actor Loss: 107.57540893554688, Critic Loss: 208.50485229492188
# Episode 131, Step 250, Total Reward: -18590.386281967163, Actor Loss: -1137.623046875, Critic Loss: 5092.02099609375
# Episode 132, Step 250, Total Reward: -10006.265712738037, Actor Loss: 1.1713520288467407, Critic Loss: 929.4459838867188
# Episode 133, Step 250, Total Reward: -11895.11946964264, Actor Loss: -583.2904663085938, Critic Loss: 1338.6380615234375
# Episode 134, Step 250, Total Reward: -11368.406303405762, Actor Loss: -1568.1180419921875, Critic Loss: 9674.9990234375
# Episode 135, Step 250, Total Reward: -14933.356378555298, Actor Loss: 4.346920263742504e-07, Critic Loss: 13.303971290588379
# Episode 136, Step 250, Total Reward: -6636.050503730774, Actor Loss: 12.38424301147461, Critic Loss: 19.374181747436523
# Episode 137, Step 250, Total Reward: -11840.454689025879, Actor Loss: -303.4268493652344, Critic Loss: 362.2442321777344
# Episode 138, Step 250, Total Reward: -8019.950318336487, Actor Loss: 29.42646598815918, Critic Loss: 4.837636947631836
# Episode 139, Step 250, Total Reward: -8909.061532974243, Actor Loss: -1713.9659423828125, Critic Loss: 11558.40234375
# Episode 140, Step 250, Total Reward: -6449.006685256958, Actor Loss: -282.56475830078125, Critic Loss: 314.14447021484375
# Episode 141, Step 250, Total Reward: -10648.245594978333, Actor Loss: -3.79220273316605e-06, Critic Loss: 1011.8953857421875
# Episode 142, Step 250, Total Reward: -9969.79263305664, Actor Loss: -601.63427734375, Critic Loss: 1424.159423828125
# Episode 143, Step 250, Total Reward: -8889.440120697021, Actor Loss: 73.38658905029297, Critic Loss: 39.74292755126953
# Episode 144, Step 250, Total Reward: -7286.5002546310425, Actor Loss: -476.7030029296875, Critic Loss: 894.1063842773438
# Episode 145, Step 250, Total Reward: -5965.900671005249, Actor Loss: -3.906893834937364e-05, Critic Loss: 0.0073433518409729
# Episode 146, Step 250, Total Reward: -10996.63372516632, Actor Loss: 1.124748706817627, Critic Loss: 1925.015625
# Episode 147, Step 250, Total Reward: -11182.93553352356, Actor Loss: -6.444056452892255e-06, Critic Loss: 2922.014892578125
# Episode 148, Step 250, Total Reward: -6924.940113067627, Actor Loss: 8.172384262084961, Critic Loss: 166.66583251953125
# Episode 149, Step 250, Total Reward: -10079.988708496094, Actor Loss: 3.0140013694763184, Critic Loss: 827.7842407226562
# Episode 150, Step 250, Total Reward: -7332.9701681137085, Actor Loss: -854.8909301757812, Critic Loss: 2875.509765625
# Episode 151, Step 250, Total Reward: -13306.853302001953, Actor Loss: -151.38259887695312, Critic Loss: 90.1665267944336
# Episode 152, Step 250, Total Reward: -11346.236549377441, Actor Loss: -212.87521362304688, Critic Loss: 178.29681396484375
# Episode 153, Step 250, Total Reward: -8668.373901367188, Actor Loss: -399.2407531738281, Critic Loss: 627.1380615234375
# Episode 154, Step 250, Total Reward: -8903.064611434937, Actor Loss: -890.987060546875, Critic Loss: 3123.461669921875
# Episode 155, Step 250, Total Reward: -6786.640137672424, Actor Loss: 1.2086086371709825e-06, Critic Loss: 102.84712982177734
# Episode 156, Step 250, Total Reward: -10916.026591300964, Actor Loss: -4.658398040646716e-07, Critic Loss: 15.262603759765625
# Episode 157, Step 250, Total Reward: -16407.489891052246, Actor Loss: -1697.4669189453125, Critic Loss: 11336.9462890625
# Episode 158, Step 250, Total Reward: -14453.453454971313, Actor Loss: -1345.9171142578125, Critic Loss: 7127.3828125
# Episode 159, Step 250, Total Reward: -10586.120063781738, Actor Loss: 7.78027413161908e-07, Critic Loss: 42.609405517578125
# Episode 160, Step 250, Total Reward: -9436.801014900208, Actor Loss: 83.14217376708984, Critic Loss: 75.94850158691406
# Episode 161, Step 250, Total Reward: -15210.466650009155, Actor Loss: -8.046076800383162e-06, Critic Loss: 4555.4921875
# Episode 162, Step 250, Total Reward: -7343.093092918396, Actor Loss: 4.120206356048584, Critic Loss: 429.69158935546875
# Episode 163, Step 250, Total Reward: -9541.246810913086, Actor Loss: 17.7168025970459, Critic Loss: 28.329111099243164
# Episode 164, Step 250, Total Reward: -6743.152403831482, Actor Loss: 8.714176177978516, Critic Loss: 143.33865356445312
# Episode 165, Step 250, Total Reward: -12476.428430557251, Actor Loss: 58.184593200683594, Critic Loss: 325.2404479980469
# Episode 166, Step 250, Total Reward: -10838.06318283081, Actor Loss: -853.4468994140625, Critic Loss: 2865.803955078125
# Episode 167, Step 250, Total Reward: -16129.882230758667, Actor Loss: 1.9865226745605469, Critic Loss: 2523.0263671875
# Episode 168, Step 250, Total Reward: -16147.073272705078, Actor Loss: -493.4822082519531, Critic Loss: 958.1564331054688
# Episode 169, Step 250, Total Reward: -7922.920431137085, Actor Loss: -934.0307006835938, Critic Loss: 3432.541015625
# Episode 170, Step 250, Total Reward: -8393.4331741333, Actor Loss: -13.055306434631348, Critic Loss: 2.2426817417144775
# Episode 171, Step 250, Total Reward: -7386.400114059448, Actor Loss: 32.7957878112793, Critic Loss: 513.0402221679688
# Episode 172, Step 250, Total Reward: -10138.31204032898, Actor Loss: -1.4390708429345977e-06, Critic Loss: 145.70423889160156
# Episode 173, Step 250, Total Reward: -8090.0702114105225, Actor Loss: 9.064911842346191, Critic Loss: 337.8559875488281
# Episode 174, Step 250, Total Reward: -5581.006700515747, Actor Loss: -1.5464376019735937e-06, Critic Loss: 168.2581329345703
# Episode 175, Step 250, Total Reward: -12642.659927368164, Actor Loss: -3.646538061730098e-06, Critic Loss: 935.64892578125
# Episode 176, Step 250, Total Reward: -10243.1411485672, Actor Loss: -384.9564208984375, Critic Loss: 583.0645141601562
# Episode 177, Step 250, Total Reward: -11254.976264953613, Actor Loss: -856.72412109375, Critic Loss: 2887.85546875
# Episode 178, Step 250, Total Reward: -8546.133450508118, Actor Loss: -31.49165916442871, Critic Loss: 3.901975154876709
# Episode 179, Step 250, Total Reward: -10465.903290748596, Actor Loss: 38.55995178222656, Critic Loss: 228.01295471191406
# Episode 180, Step 250, Total Reward: -14686.81923866272, Actor Loss: 6.250847339630127, Critic Loss: 0.15373444557189941
# Episode 181, Step 250, Total Reward: -16478.386959075928, Actor Loss: -589.420654296875, Critic Loss: 1366.923095703125
# Episode 182, Step 250, Total Reward: -10200.770551681519, Actor Loss: -2.55054601439042e-06, Critic Loss: 457.7259521484375
# Episode 183, Step 250, Total Reward: -10923.229888916016, Actor Loss: -1078.6641845703125, Critic Loss: 4577.89697265625
# Episode 184, Step 250, Total Reward: -7933.274039268494, Actor Loss: 7.743106365203857, Critic Loss: 90.90523529052734
# Episode 185, Step 250, Total Reward: -9811.390008926392, Actor Loss: 0.00011599400750128552, Critic Loss: 108.55950927734375
# Episode 186, Step 250, Total Reward: -10801.010164260864, Actor Loss: -3200.550537109375, Critic Loss: 40303.50390625
# Episode 187, Step 250, Total Reward: -6135.786079406738, Actor Loss: -2.232950691904989e-06, Critic Loss: 350.8258972167969
# Episode 188, Step 250, Total Reward: -10679.949889183044, Actor Loss: -1179.421142578125, Critic Loss: 5473.07373046875
# Episode 189, Step 250, Total Reward: -15661.470170974731, Actor Loss: -99.19619750976562, Critic Loss: 38.71537399291992
# Episode 190, Step 250, Total Reward: -6640.186924934387, Actor Loss: -83.41728210449219, Critic Loss: 27.378238677978516
# Episode 191, Step 250, Total Reward: -5615.7401876449585, Actor Loss: 0.010049496777355671, Critic Loss: 0.962037205696106
# Episode 192, Step 250, Total Reward: -14591.006759643555, Actor Loss: -479.2212219238281, Critic Loss: 903.5777587890625
# Episode 193, Step 250, Total Reward: -11386.679767608643, Actor Loss: -505.7181396484375, Critic Loss: 1162.716796875
# Episode 194, Step 250, Total Reward: -8807.379709243774, Actor Loss: 164.13710021972656, Critic Loss: 119.15939331054688
# Episode 195, Step 250, Total Reward: -12146.270197868347, Actor Loss: 17.262025833129883, Critic Loss: 787.161376953125
# Episode 196, Step 250, Total Reward: -15026.449382781982, Actor Loss: -1.0321992931494606e-06, Critic Loss: 74.95602416992188
# Episode 197, Step 250, Total Reward: -6031.404906272888, Actor Loss: -224.54202270507812, Critic Loss: 198.3758087158203
# Episode 198, Step 250, Total Reward: -7611.416971206665, Actor Loss: 0.00039644475327804685, Critic Loss: 24.090457916259766
# Episode 199, Step 250, Total Reward: -8815.065490722656, Actor Loss: -116.20893096923828, Critic Loss: 53.13399124145508
# Episode 200, Step 250, Total Reward: -8835.40989112854, Actor Loss: 65.38087463378906, Critic Loss: 1242.21826171875
# Episode 201, Step 250, Total Reward: -7229.0271253585815, Actor Loss: -6.59718656539917, Critic Loss: 0.5566558837890625
# Episode 202, Step 250, Total Reward: -8489.659853935242, Actor Loss: -551.0942993164062, Critic Loss: 1194.937744140625
# Episode 203, Step 250, Total Reward: -6072.160223007202, Actor Loss: 2.051536830549594e-05, Critic Loss: 4.150809288024902
# Episode 204, Step 250, Total Reward: -7200.580241203308, Actor Loss: -260.7957763671875, Critic Loss: 267.6051940917969
# Episode 205, Step 250, Total Reward: -12715.069792747498, Actor Loss: -3.035557369912567e-07, Critic Loss: 6.47911262512207
# Episode 206, Step 250, Total Reward: -8476.240399360657, Actor Loss: -80.27629089355469, Critic Loss: 25.355257034301758
# Episode 207, Step 250, Total Reward: -5859.100161552429, Actor Loss: -2.146846782125067e-06, Critic Loss: 324.29010009765625
# Episode 208, Step 250, Total Reward: -7005.197380065918, Actor Loss: 0.1718720644712448, Critic Loss: 551.5846557617188
# Episode 209, Step 250, Total Reward: -12333.75996208191, Actor Loss: 91.77680969238281, Critic Loss: 75.88468933105469
# Episode 210, Step 250, Total Reward: -12613.72463130951, Actor Loss: 108.85922241210938, Critic Loss: 694.996826171875
# Episode 211, Step 250, Total Reward: -7700.121221542358, Actor Loss: -75.54164123535156, Critic Loss: 27.472850799560547
# Episode 212, Step 250, Total Reward: -5592.646987915039, Actor Loss: 8.26041316986084, Critic Loss: 33.95992660522461
# Episode 213, Step 250, Total Reward: -8975.906635284424, Actor Loss: 45.56549072265625, Critic Loss: 564.7933349609375
# Episode 214, Step 250, Total Reward: -7566.360181808472, Actor Loss: -270.4873046875, Critic Loss: 287.8639221191406
# Episode 215, Step 250, Total Reward: -7253.500335693359, Actor Loss: 4.3240065574646, Critic Loss: 250.22048950195312
# Episode 216, Step 250, Total Reward: -7778.946696281433, Actor Loss: -4.068161274517479e-07, Critic Loss: 11.639158248901367
# Episode 217, Step 250, Total Reward: -8543.307007789612, Actor Loss: -31.09110450744629, Critic Loss: 4.104185104370117
# Episode 218, Step 250, Total Reward: -8529.939474105835, Actor Loss: -60.698604583740234, Critic Loss: 14.496089935302734
# Episode 219, Step 250, Total Reward: -7242.4001178741455, Actor Loss: 2.163841799074362e-07, Critic Loss: 3.2984447479248047
# Episode 220, Step 250, Total Reward: -8045.080164909363, Actor Loss: -2.8238942623138428, Critic Loss: 10.200662612915039
# Episode 221, Step 250, Total Reward: -11370.3321018219, Actor Loss: -7.9939680099487305, Critic Loss: 19.570255279541016
# Episode 222, Step 250, Total Reward: -6143.720683097839, Actor Loss: -120.37918090820312, Critic Loss: 58.349308013916016
# Episode 223, Step 250, Total Reward: -6506.113181114197, Actor Loss: 13.826790809631348, Critic Loss: 134.6982421875
# Episode 224, Step 250, Total Reward: -6043.626838684082, Actor Loss: -4.036994934082031, Critic Loss: 0.1854715347290039
# Episode 225, Step 250, Total Reward: -9298.7282705307, Actor Loss: -2.9005777832935564e-06, Critic Loss: 591.9883422851562
# Episode 226, Step 250, Total Reward: -11574.496974945068, Actor Loss: 21.34189224243164, Critic Loss: 746.0126953125
# Episode 227, Step 250, Total Reward: -5750.570560455322, Actor Loss: -237.853759765625, Critic Loss: 236.57833862304688
# Episode 228, Step 250, Total Reward: -5333.574136734009, Actor Loss: 3.7048845291137695, Critic Loss: 9.184776306152344
# Episode 229, Step 250, Total Reward: -9951.375045776367, Actor Loss: -1111.673828125, Critic Loss: 4862.37255859375
# Episode 230, Step 250, Total Reward: -10318.666902542114, Actor Loss: 0.0003132195270154625, Critic Loss: 38.44544982910156
# Episode 231, Step 250, Total Reward: -12078.325841903687, Actor Loss: 46.26448440551758, Critic Loss: 651.4458618164062
# Episode 232, Step 250, Total Reward: -7303.926981925964, Actor Loss: 6.219659553607926e-06, Critic Loss: 303.0285339355469
# Episode 233, Step 250, Total Reward: -6581.123670578003, Actor Loss: -648.4436645507812, Critic Loss: 1654.39013671875
# Episode 234, Step 250, Total Reward: -8134.62038230896, Actor Loss: 0.04033172130584717, Critic Loss: 293.0482482910156
# Episode 235, Step 250, Total Reward: -8967.995774269104, Actor Loss: 3.3642936614342034e-06, Critic Loss: 65.2837142944336
# Episode 236, Step 250, Total Reward: -7062.486947059631, Actor Loss: -1.2420670145729673e-06, Critic Loss: 108.5391616821289
# Episode 237, Step 250, Total Reward: -8405.813474655151, Actor Loss: -850.9286499023438, Critic Loss: 2848.916748046875
# Episode 238, Step 250, Total Reward: -7844.650340080261, Actor Loss: -107.75900268554688, Critic Loss: 45.68783187866211
# Episode 239, Step 250, Total Reward: -8448.825653076172, Actor Loss: -73.65731048583984, Critic Loss: 80.17156219482422
# Episode 240, Step 250, Total Reward: -8278.031405448914, Actor Loss: 0.10852238535881042, Critic Loss: 754.7066040039062
# Episode 241, Step 250, Total Reward: -9318.966750144958, Actor Loss: 6.589141845703125, Critic Loss: 329.93316650390625
# Episode 242, Step 250, Total Reward: -11655.836736679077, Actor Loss: 20.95268440246582, Critic Loss: 954.954833984375
# Episode 243, Step 250, Total Reward: -5824.473734855652, Actor Loss: -220.24700927734375, Critic Loss: 190.85934448242188
# Episode 244, Step 250, Total Reward: -7697.260277748108, Actor Loss: -404.33563232421875, Critic Loss: 643.2465209960938
# Episode 245, Step 250, Total Reward: -7288.804481506348, Actor Loss: -243.0279541015625, Critic Loss: 232.38381958007812
# Episode 246, Step 250, Total Reward: -5684.280529975891, Actor Loss: -527.9280395507812, Critic Loss: 1096.58642578125
# Episode 247, Step 250, Total Reward: -8995.59990978241, Actor Loss: -595.632568359375, Critic Loss: 1395.8870849609375
# Episode 248, Step 250, Total Reward: -9442.129968643188, Actor Loss: -4.10335178457899e-06, Critic Loss: 1184.7646484375
# Episode 249, Step 250, Total Reward: -5984.4738302230835, Actor Loss: 0.004151222761720419, Critic Loss: 13.357454299926758
# Episode 250, Step 250, Total Reward: -6380.433482170105, Actor Loss: 33.58193588256836, Critic Loss: 64.54804229736328
# Episode 251, Step 250, Total Reward: -11672.440444946289, Actor Loss: 8.724135227566876e-07, Critic Loss: 53.57267761230469
# Episode 252, Step 250, Total Reward: -6416.070339202881, Actor Loss: 17.096511840820312, Critic Loss: 86.759033203125
# Episode 253, Step 250, Total Reward: -6783.760739326477, Actor Loss: -1.7696903569230926e-06, Critic Loss: 220.35140991210938
# Episode 254, Step 250, Total Reward: -9941.687156677246, Actor Loss: -225.31072998046875, Critic Loss: 199.73638916015625
# Episode 255, Step 250, Total Reward: -7430.333103179932, Actor Loss: -7.858652679715306e-07, Critic Loss: 43.445350646972656
# Episode 256, Step 250, Total Reward: -8219.44711112976, Actor Loss: 0.8871474862098694, Critic Loss: 183.0616912841797
# Episode 257, Step 250, Total Reward: -10968.040201187134, Actor Loss: -518.9331665039062, Critic Loss: 1059.5374755859375
# Episode 258, Step 250, Total Reward: -7911.640273094177, Actor Loss: 0.7571600079536438, Critic Loss: 253.33509826660156
# Episode 259, Step 250, Total Reward: -8586.52171421051, Actor Loss: 11.455636978149414, Critic Loss: 187.04702758789062
# Episode 260, Step 250, Total Reward: -6845.453572273254, Actor Loss: 1.8884921073913574, Critic Loss: 129.98004150390625
# Episode 261, Step 250, Total Reward: -11348.850071907043, Actor Loss: -1.3072013871351373e-06, Critic Loss: 120.22244262695312
# Episode 262, Step 250, Total Reward: -8465.177728652954, Actor Loss: 2.902982473373413, Critic Loss: 206.78103637695312
# Episode 263, Step 250, Total Reward: -11315.549689292908, Actor Loss: -146.71975708007812, Critic Loss: 84.697509765625
# Episode 264, Step 250, Total Reward: -13246.797105789185, Actor Loss: -1209.3209228515625, Critic Loss: 5754.08935546875
# Episode 265, Step 250, Total Reward: -6696.787226676941, Actor Loss: -5.042557518208923e-07, Critic Loss: 17.88447380065918
# Episode 266, Step 250, Total Reward: -7683.200705528259, Actor Loss: -313.3597106933594, Critic Loss: 386.3489685058594
# Episode 267, Step 250, Total Reward: -6440.113443374634, Actor Loss: 0.2886956036090851, Critic Loss: 30.153396606445312
# Episode 268, Step 250, Total Reward: -5642.840692520142, Actor Loss: -3.498643650345912e-07, Critic Loss: 8.58306884765625
# Episode 269, Step 250, Total Reward: -5577.066799163818, Actor Loss: -281.097412109375, Critic Loss: 310.8902587890625
# Episode 270, Step 250, Total Reward: -11526.083683013916, Actor Loss: 2.7918404157389887e-06, Critic Loss: 548.5270385742188
# Episode 271, Step 250, Total Reward: -10005.190460205078, Actor Loss: -8.653852091811132e-06, Critic Loss: 5269.7109375
# Episode 272, Step 250, Total Reward: -13122.476009368896, Actor Loss: 45.358890533447266, Critic Loss: 868.7957763671875
# Episode 273, Step 250, Total Reward: -6413.270896911621, Actor Loss: 7.870353698730469, Critic Loss: 35.39320373535156
# Episode 274, Step 250, Total Reward: -7501.0534925460815, Actor Loss: -724.9659423828125, Critic Loss: 2067.895751953125
# Episode 275, Step 250, Total Reward: -6988.362699508667, Actor Loss: 3.971726982854307e-06, Critic Loss: 69.64668273925781
# Episode 276, Step 250, Total Reward: -6001.7807970047, Actor Loss: -318.8866271972656, Critic Loss: 400.09765625
# Episode 277, Step 250, Total Reward: -6656.373511314392, Actor Loss: -1.7688137177174212e-07, Critic Loss: 2.198298454284668
# Episode 278, Step 250, Total Reward: -5495.8793687820435, Actor Loss: -23.605222702026367, Critic Loss: 6.364040851593018
# Episode 279, Step 250, Total Reward: -8640.813271522522, Actor Loss: -298.9586486816406, Critic Loss: 351.654052734375
# Episode 280, Step 250, Total Reward: -8562.50023841858, Actor Loss: -4.14665828429861e-06, Critic Loss: 1209.9051513671875
# Episode 281, Step 250, Total Reward: -7646.700849533081, Actor Loss: 35.33791732788086, Critic Loss: 11.060171127319336
# Episode 282, Step 250, Total Reward: -7575.326686859131, Actor Loss: -1.8419551679471624e-06, Critic Loss: 238.71607971191406
# Episode 283, Step 250, Total Reward: -6876.353727340698, Actor Loss: 0.04597033932805061, Critic Loss: 28.99833106994629
# Episode 284, Step 250, Total Reward: -11114.279957771301, Actor Loss: -967.4918212890625, Critic Loss: 3682.8837890625
# Episode 285, Step 250, Total Reward: -6109.390709877014, Actor Loss: -1.7578414678573608, Critic Loss: 0.2824860215187073
# Episode 286, Step 250, Total Reward: -12394.286762237549, Actor Loss: 0.00017904820560943335, Critic Loss: 154.3818359375
# Episode 287, Step 250, Total Reward: -7196.516082763672, Actor Loss: -3.226540684408974e-06, Critic Loss: 732.5242919921875
# Episode 288, Step 250, Total Reward: -10062.356608390808, Actor Loss: -6.102810061747732e-07, Critic Loss: 26.198102951049805
# Episode 289, Step 250, Total Reward: -7705.345603942871, Actor Loss: -752.1995239257812, Critic Loss: 2226.17626953125
# Episode 290, Step 250, Total Reward: -7452.926376342773, Actor Loss: -224.94097900390625, Critic Loss: 199.08135986328125
# Episode 291, Step 250, Total Reward: -8350.72023677826, Actor Loss: 21.998302459716797, Critic Loss: 49.05812454223633
# Episode 292, Step 250, Total Reward: -9428.309889793396, Actor Loss: 21.520954132080078, Critic Loss: 70.59938049316406
# Episode 293, Step 250, Total Reward: -9997.676748275757, Actor Loss: 1.1010823754986632e-06, Critic Loss: 85.33230590820312
# Episode 294, Step 250, Total Reward: -6133.686995506287, Actor Loss: -208.83901977539062, Critic Loss: 171.59976196289062
# Episode 295, Step 250, Total Reward: -7806.166977882385, Actor Loss: -487.2294006347656, Critic Loss: 934.0291137695312
# Episode 296, Step 250, Total Reward: -7908.153227806091, Actor Loss: -136.0357208251953, Critic Loss: 72.81138610839844
# Episode 297, Step 250, Total Reward: -7342.706879615784, Actor Loss: 7.288833216989588e-07, Critic Loss: 37.4110221862793
# Episode 298, Step 250, Total Reward: -7732.556736946106, Actor Loss: -725.3434448242188, Critic Loss: 2070.050048828125
# Episode 299, Step 250, Total Reward: -5702.460136413574, Actor Loss: 0.04212182015180588, Critic Loss: 427.95245361328125
# Episode 300, Step 250, Total Reward: -6655.746906280518, Actor Loss: -381.6402893066406, Critic Loss: 573.0623779296875
# Episode 301, Step 250, Total Reward: -9642.756427764893, Actor Loss: 1.4353689721247065e-06, Critic Loss: 145.00369262695312
# Episode 302, Step 250, Total Reward: -6574.180364608765, Actor Loss: -5.662039370690763e-07, Critic Loss: 22.549745559692383
# Episode 303, Step 250, Total Reward: -5549.078309059143, Actor Loss: 5.331940650939941, Critic Loss: 17.290653228759766
# Episode 304, Step 250, Total Reward: -9155.026797294617, Actor Loss: -690.6875, Critic Loss: 1876.966796875
# Episode 305, Step 250, Total Reward: -7246.973767280579, Actor Loss: 52.88457489013672, Critic Loss: 17.126585006713867
# Episode 306, Step 250, Total Reward: -5808.3435735702515, Actor Loss: 0.359264999628067, Critic Loss: 0.005876779556274414
# Episode 307, Step 250, Total Reward: -12245.970160484314, Actor Loss: -65.47822570800781, Critic Loss: 16.86890983581543
# Episode 308, Step 250, Total Reward: -8799.834697723389, Actor Loss: -122.42085266113281, Critic Loss: 58.96635055541992
# Episode 309, Step 250, Total Reward: -12969.613605499268, Actor Loss: 4.478760615711508e-07, Critic Loss: 14.122989654541016
# Episode 310, Step 250, Total Reward: -6353.340861320496, Actor Loss: 0.003338972572237253, Critic Loss: 4.387879371643066
# Episode 311, Step 250, Total Reward: -9221.801942825317, Actor Loss: -746.7699584960938, Critic Loss: 2194.154052734375
# Episode 312, Step 250, Total Reward: -6391.747011184692, Actor Loss: 43.75222396850586, Critic Loss: 60.93220138549805
# Episode 313, Step 250, Total Reward: -8001.939712524414, Actor Loss: 3.809196949005127, Critic Loss: 86.41372680664062
# Episode 314, Step 250, Total Reward: -7952.00700378418, Actor Loss: -0.09652078151702881, Critic Loss: 19.082990646362305
# Episode 315, Step 250, Total Reward: -6980.459920883179, Actor Loss: 34.209686279296875, Critic Loss: 71.76522064208984
# Episode 316, Step 250, Total Reward: -9855.823125839233, Actor Loss: 3.814340114593506, Critic Loss: 0.057244300842285156
# Episode 317, Step 250, Total Reward: -5984.551878929138, Actor Loss: 0.22839044034481049, Critic Loss: 11.31412410736084
# Episode 318, Step 250, Total Reward: -11566.60015964508, Actor Loss: -841.85986328125, Critic Loss: 2788.515625
# Episode 319, Step 250, Total Reward: -5739.493383407593, Actor Loss: -197.57687377929688, Critic Loss: 199.074462890625
# Episode 320, Step 250, Total Reward: -9752.298543930054, Actor Loss: 19.025577545166016, Critic Loss: 78.53179168701172
# Episode 321, Step 250, Total Reward: -6143.3647747039795, Actor Loss: -107.61305236816406, Critic Loss: 45.56414794921875
# Episode 322, Step 250, Total Reward: -5777.880401611328, Actor Loss: -0.0002824590774253011, Critic Loss: 2.035637855529785
# Episode 323, Step 250, Total Reward: -6783.783303260803, Actor Loss: -55.553138732910156, Critic Loss: 12.142570495605469
# Episode 324, Step 250, Total Reward: -5893.920333862305, Actor Loss: -543.0355224609375, Critic Loss: 1160.24560546875
# Episode 325, Step 250, Total Reward: -7316.80678653717, Actor Loss: 7.89525017808046e-07, Critic Loss: 44.09465789794922
# Episode 326, Step 250, Total Reward: -6007.0004529953, Actor Loss: -67.23941802978516, Critic Loss: 17.788583755493164
# Episode 327, Step 250, Total Reward: -6861.42684841156, Actor Loss: 15.133398056030273, Critic Loss: 18.789770126342773
# Episode 328, Step 250, Total Reward: -5855.813632011414, Actor Loss: -37.144073486328125, Critic Loss: 7.0291008949279785
# Episode 329, Step 250, Total Reward: -5844.3304271698, Actor Loss: -215.13267517089844, Critic Loss: 182.09841918945312
# Episode 330, Step 250, Total Reward: -11424.683656692505, Actor Loss: -2.711344677663874e-06, Critic Loss: 517.2626342773438
# Episode 331, Step 250, Total Reward: -7330.56344127655, Actor Loss: -1.9106109903077595e-06, Critic Loss: 256.8444519042969
# Episode 332, Step 250, Total Reward: -8707.986916542053, Actor Loss: 195.4226531982422, Critic Loss: 150.25994873046875
# Episode 333, Step 250, Total Reward: -7812.12038230896, Actor Loss: 0.18163657188415527, Critic Loss: 293.8763427734375
# Episode 334, Step 250, Total Reward: -7416.980265617371, Actor Loss: -748.09326171875, Critic Loss: 2201.937255859375
# Episode 335, Step 250, Total Reward: -7007.220083236694, Actor Loss: 16.369937896728516, Critic Loss: 100.0927963256836
# Episode 336, Step 250, Total Reward: -6982.427704811096, Actor Loss: -28.739910125732422, Critic Loss: 3.2498512268066406
# Episode 337, Step 250, Total Reward: -8801.40760421753, Actor Loss: 21.18436622619629, Critic Loss: 23.751344680786133
# Episode 338, Step 250, Total Reward: -6730.840038299561, Actor Loss: -115.33319091796875, Critic Loss: 52.336181640625
# Episode 339, Step 250, Total Reward: -7873.5740394592285, Actor Loss: -38.859561920166016, Critic Loss: 5.94140625
# Episode 340, Step 250, Total Reward: -6608.860321044922, Actor Loss: 31.444974899291992, Critic Loss: 39.638336181640625
# Episode 341, Step 250, Total Reward: -6795.107123374939, Actor Loss: -74.0673828125, Critic Loss: 30.784074783325195
# Episode 342, Step 250, Total Reward: -5827.53120803833, Actor Loss: -7.165245392570796e-07, Critic Loss: 36.115814208984375
# Episode 343, Step 250, Total Reward: -6464.146719932556, Actor Loss: 0.01853625476360321, Critic Loss: 0.3801673650741577
# Episode 344, Step 250, Total Reward: -7390.960534095764, Actor Loss: 48.04121780395508, Critic Loss: 9.0807466506958
# Episode 345, Step 250, Total Reward: -9109.95389175415, Actor Loss: -1375.355712890625, Critic Loss: 7442.57958984375
# Episode 346, Step 250, Total Reward: -4804.355377197266, Actor Loss: -129.051513671875, Critic Loss: 91.35738372802734
# Episode 347, Step 250, Total Reward: -6440.340764045715, Actor Loss: 4.809816687156854e-07, Critic Loss: 16.287412643432617
# Episode 348, Step 250, Total Reward: -8121.4866065979, Actor Loss: -243.37435913085938, Critic Loss: 233.04676818847656
# Episode 349, Step 250, Total Reward: -6262.293838500977, Actor Loss: -193.39093017578125, Critic Loss: 147.15182495117188
# Episode 350, Step 250, Total Reward: -6938.734269142151, Actor Loss: -40.28410339355469, Critic Loss: 6.384998321533203
# Episode 351, Step 250, Total Reward: -6126.793703079224, Actor Loss: -418.14508056640625, Critic Loss: 687.93505859375
# Episode 352, Step 250, Total Reward: -6892.570538520813, Actor Loss: 32.818565368652344, Critic Loss: 25.17854118347168
# Episode 353, Step 250, Total Reward: -7601.393621444702, Actor Loss: 0.007447327021509409, Critic Loss: 30.982160568237305
# Episode 354, Step 250, Total Reward: -9181.376138687134, Actor Loss: -1191.0238037109375, Critic Loss: 5581.28662109375
# Episode 355, Step 250, Total Reward: -5967.120154380798, Actor Loss: -2.7830419639940374e-06, Critic Loss: 544.98193359375
# Episode 356, Step 250, Total Reward: -7570.006826400757, Actor Loss: -5.746579176957312e-07, Critic Loss: 23.228351593017578
# Episode 357, Step 250, Total Reward: -6281.507176399231, Actor Loss: -4.362759590148926, Critic Loss: 0.3098487854003906
# Episode 358, Step 250, Total Reward: -6697.6007289886475, Actor Loss: -11.843914985656738, Critic Loss: 0.5519300103187561
# Episode 359, Step 250, Total Reward: -7540.913323402405, Actor Loss: -715.41064453125, Critic Loss: 2013.7437744140625
# Episode 360, Step 250, Total Reward: -6123.693960189819, Actor Loss: -76.25371551513672, Critic Loss: 22.877864837646484
# Episode 361, Step 250, Total Reward: -9691.060062408447, Actor Loss: -1663.5115966796875, Critic Loss: 10887.923828125
# Episode 362, Step 250, Total Reward: -9518.589950561523, Actor Loss: -42.99695587158203, Critic Loss: 7.273924827575684
# Episode 363, Step 250, Total Reward: -9073.470212936401, Actor Loss: -749.0935668945312, Critic Loss: 2207.829833984375
# Episode 364, Step 250, Total Reward: -6467.19376373291, Actor Loss: 4.338327407836914, Critic Loss: 41.61919403076172
# Episode 365, Step 250, Total Reward: -12144.180037498474, Actor Loss: 87.56729125976562, Critic Loss: 561.4562377929688
# Episode 366, Step 250, Total Reward: -6511.23352432251, Actor Loss: 34.002506256103516, Critic Loss: 103.68071746826172
# Episode 367, Step 250, Total Reward: -7210.753476142883, Actor Loss: 2.5986491891671903e-06, Critic Loss: 475.24212646484375
# Episode 368, Step 250, Total Reward: -4994.406867980957, Actor Loss: 3.8074285984039307, Critic Loss: 0.12932592630386353
# Episode 369, Step 250, Total Reward: -6569.760730743408, Actor Loss: -15.938268661499023, Critic Loss: 3.332674980163574
# Episode 370, Step 250, Total Reward: -7236.373653411865, Actor Loss: 0.2965177297592163, Critic Loss: 14.930602073669434
# Episode 371, Step 250, Total Reward: -6669.46706199646, Actor Loss: 19.761295318603516, Critic Loss: 11.450028419494629
# Episode 372, Step 250, Total Reward: -7043.821365356445, Actor Loss: -479.2912902832031, Critic Loss: 903.8419799804688
# Episode 373, Step 250, Total Reward: -10506.71973991394, Actor Loss: 7.227779388427734, Critic Loss: 0.20554357767105103
# Episode 374, Step 250, Total Reward: -7605.639851570129, Actor Loss: -1.7714656905809534e-06, Critic Loss: 220.7937774658203
# Episode 375, Step 250, Total Reward: -6047.507099151611, Actor Loss: -8.817056655883789, Critic Loss: 0.6485046148300171
# Episode 376, Step 250, Total Reward: -6332.741027832031, Actor Loss: 0.10443193465471268, Critic Loss: 13.12735366821289
# Episode 377, Step 250, Total Reward: -5370.2533893585205, Actor Loss: 25.249164581298828, Critic Loss: 45.697731018066406
# Episode 378, Step 250, Total Reward: -7082.640205383301, Actor Loss: -0.8329923748970032, Critic Loss: 0.025963783264160156
# Episode 379, Step 250, Total Reward: -11257.276718139648, Actor Loss: 259.4554443359375, Critic Loss: 975.586181640625
# Episode 380, Step 250, Total Reward: -8541.083515167236, Actor Loss: -80.94600677490234, Critic Loss: 33.87887954711914
# Episode 381, Step 250, Total Reward: -11033.895502090454, Actor Loss: -37.5946044921875, Critic Loss: 5.560891628265381
# Episode 382, Step 250, Total Reward: -5985.124354362488, Actor Loss: -3.5979637686978094e-06, Critic Loss: 910.88720703125
# Episode 383, Step 250, Total Reward: -8945.500294685364, Actor Loss: 48.149410247802734, Critic Loss: 18.185144424438477
# Episode 384, Step 250, Total Reward: -6670.720284461975, Actor Loss: -479.4041748046875, Critic Loss: 904.2677612304688
# Episode 385, Step 250, Total Reward: -6356.700432777405, Actor Loss: -1.6982404531518114e-06, Critic Loss: 202.91641235351562
# Episode 386, Step 250, Total Reward: -5887.307149887085, Actor Loss: 11.661694526672363, Critic Loss: 30.094438552856445
# Episode 387, Step 250, Total Reward: -7109.193601608276, Actor Loss: 13.92879581451416, Critic Loss: 21.954349517822266
# Episode 388, Step 250, Total Reward: -6368.830606460571, Actor Loss: -823.286376953125, Critic Loss: 2666.829833984375
# Episode 389, Step 250, Total Reward: -6432.033693313599, Actor Loss: 27.574268341064453, Critic Loss: 22.399282455444336
# Episode 390, Step 250, Total Reward: -6171.600306510925, Actor Loss: -8.509699821472168, Critic Loss: 0.5968844890594482
# Episode 391, Step 250, Total Reward: -8442.120168685913, Actor Loss: -7.194758211426233e-08, Critic Loss: 0.3630533218383789
# Episode 392, Step 250, Total Reward: -5949.853633880615, Actor Loss: 0.4792157709598541, Critic Loss: 0.7253665924072266
# Episode 393, Step 250, Total Reward: -5931.567000389099, Actor Loss: -7.816467473276134e-07, Critic Loss: 42.829612731933594
# Episode 394, Step 250, Total Reward: -5777.247078895569, Actor Loss: -1.1735565976778162e-06, Critic Loss: 96.89460754394531
# Episode 395, Step 250, Total Reward: -7900.556721687317, Actor Loss: -384.726806640625, Critic Loss: 582.3690795898438
# Episode 396, Step 250, Total Reward: -5808.440625190735, Actor Loss: 2.6014689069597807e-07, Critic Loss: 4.767548561096191
# Episode 397, Step 250, Total Reward: -6436.084564208984, Actor Loss: -336.9074401855469, Critic Loss: 446.59576416015625
# Episode 398, Step 250, Total Reward: -5284.343993186951, Actor Loss: 51.35019302368164, Critic Loss: 58.45378875732422
# ...
# Episode 4878, Step 250, Total Reward: -4062.033344268799, Actor Loss: -30.534181594848633, Critic Loss: 3.6683096885681152
# Episode 4879, Step 250, Total Reward: -4870.900026321411, Actor Loss: -10.701362609863281, Critic Loss: 2.0457520484924316
# Episode 4880, Step 250, Total Reward: -4744.881385803223, Actor Loss: 4.348228443973312e-09, Critic Loss: 0.0014044195413589478
# Episode 4881, Step 250, Total Reward: -4889.666391372681, Actor Loss: 2.1628905333415105e-09, Critic Loss: 0.0003672987222671509
# Episode 4882, Step 250, Total Reward: -6020.6895360946655, Actor Loss: -1.2535738003194297e-09, Critic Loss: 5.960464477539063e-08
# Episode 4883, Step 250, Total Reward: -3863.419839859009, Actor Loss: -7.467926721460572e-09, Critic Loss: 0.0038001686334609985
# Episode 4884, Step 250, Total Reward: -5677.826815605164, Actor Loss: -1.545297001470658e-09, Critic Loss: 0.0001431107521057129
# Episode 4885, Step 250, Total Reward: -5379.240074157715, Actor Loss: -4.975591050282446e-10, Critic Loss: 1.0073184967041016e-05
# Episode 4886, Step 250, Total Reward: -4823.95343208313, Actor Loss: -1.7072190772182694e-08, Critic Loss: 0.020224228501319885
# Episode 4887, Step 250, Total Reward: -4157.613410949707, Actor Loss: 1.3514083718746406e-07, Critic Loss: 1.2874159812927246
# Episode 4888, Step 250, Total Reward: -4878.2800941467285, Actor Loss: 3.970992779045446e-08, Critic Loss: 0.12601113319396973
# Episode 4889, Step 250, Total Reward: -4633.183839797974, Actor Loss: -43.00084686279297, Critic Loss: 7.275241851806641
# Episode 4890, Step 250, Total Reward: -4791.692985534668, Actor Loss: 5.704071526224652e-08, Critic Loss: 0.22991275787353516
# Episode 4891, Step 250, Total Reward: -4077.486198425293, Actor Loss: 3.1258640120768177e-09, Critic Loss: 0.0007410198450088501
# Episode 4892, Step 250, Total Reward: -5164.566825866699, Actor Loss: -24.767911911010742, Critic Loss: 2.4136383533477783
# Episode 4893, Step 250, Total Reward: -4305.005706787109, Actor Loss: -2.2107270181148664e-10, Critic Loss: 7.301568984985352e-07
# Episode 4894, Step 250, Total Reward: -4813.687183380127, Actor Loss: -3.0838454012638294e-10, Critic Loss: 2.518296241760254e-06
# Episode 4895, Step 250, Total Reward: -3944.3271322250366, Actor Loss: -8.177052923663553e-10, Critic Loss: 3.4332275390625e-05
# Episode 4896, Step 250, Total Reward: -4346.999387741089, Actor Loss: -45.68061447143555, Critic Loss: 8.210268020629883
# Episode 4897, Step 250, Total Reward: -6051.266954421997, Actor Loss: 1.2777745528325113e-09, Critic Loss: 0.0001373291015625
# Episode 4898, Step 250, Total Reward: -5451.173400878906, Actor Loss: 2.252357056420351e-08, Critic Loss: 0.03607773780822754
# Episode 4899, Step 250, Total Reward: -4945.799667358398, Actor Loss: 6.433474197820033e-08, Critic Loss: 0.29256582260131836
# Episode 4900, Step 250, Total Reward: -5219.863925933838, Actor Loss: -3.866607922731191e-09, Critic Loss: 0.0008229166269302368
# Episode 4901, Step 250, Total Reward: -5216.736614227295, Actor Loss: 2.4712946355975873e-07, Critic Loss: 0.4986855983734131
# Episode 4902, Step 250, Total Reward: -5640.9309940338135, Actor Loss: -34.08385467529297, Critic Loss: 4.570785045623779
# Episode 4903, Step 250, Total Reward: -5230.760292053223, Actor Loss: 4.1912029402624285e-10, Critic Loss: 2.039968967437744e-05
# Episode 4904, Step 250, Total Reward: -5865.713020324707, Actor Loss: -1.3993401637435454e-07, Critic Loss: 1.3755807876586914
# Episode 4905, Step 250, Total Reward: -5087.333024024963, Actor Loss: 1.2486707223757776e-09, Critic Loss: 0.0001316666603088379
# Episode 4906, Step 250, Total Reward: -3918.1863622665405, Actor Loss: -2.6077630519866943, Critic Loss: 0.02675652503967285
# Episode 4907, Step 250, Total Reward: -5109.936134338379, Actor Loss: -9.796233157999268e-09, Critic Loss: 0.00658966600894928
# Episode 4908, Step 250, Total Reward: -3676.123754501343, Actor Loss: 2.8824431730356537e-10, Critic Loss: 1.1682510375976562e-05
# Episode 4909, Step 250, Total Reward: -4878.726372718811, Actor Loss: -65.57940673828125, Critic Loss: 16.921091079711914
# Episode 4910, Step 250, Total Reward: -5270.494331359863, Actor Loss: -4.557543231697991e-09, Critic Loss: 0.0013861805200576782
# Episode 4911, Step 250, Total Reward: -5330.308807373047, Actor Loss: 7.782085020835439e-08, Critic Loss: 0.42746567726135254
# Episode 4912, Step 250, Total Reward: -5057.299518585205, Actor Loss: -0.14206470549106598, Critic Loss: 7.940828800201416e-05
# Episode 4913, Step 250, Total Reward: -5010.469532012939, Actor Loss: 7.684575198396715e-10, Critic Loss: 5.544722080230713e-05
# Episode 4914, Step 250, Total Reward: -5169.626123428345, Actor Loss: -6.139744268551794e-10, Critic Loss: 1.722574234008789e-05
# Episode 4915, Step 250, Total Reward: -5128.93327331543, Actor Loss: 6.123562545923278e-09, Critic Loss: 0.0027424246072769165
# Episode 4916, Step 250, Total Reward: -4029.5735635757446, Actor Loss: -6.252793312072754, Critic Loss: 0.15383018553256989
# Episode 4917, Step 250, Total Reward: -4799.120656967163, Actor Loss: -1.656763544133355e-07, Critic Loss: 1.928748607635498
# Episode 4918, Step 250, Total Reward: -4150.8405838012695, Actor Loss: -1.574401387038904e-09, Critic Loss: 0.00014901161193847656
# Episode 4919, Step 250, Total Reward: -3930.9872131347656, Actor Loss: -2.0837178649202315e-09, Critic Loss: 0.00027157366275787354
# Episode 4920, Step 250, Total Reward: -5743.073631286621, Actor Loss: -31.12968635559082, Critic Loss: 3.8127901554107666
# Episode 4921, Step 250, Total Reward: -5295.7800006866455, Actor Loss: -0.0012058075517416, Critic Loss: 5.699923038482666
# Episode 4922, Step 250, Total Reward: -3476.765899658203, Actor Loss: 1.6270205183133157e-09, Critic Loss: 0.00021457672119140625
# Episode 4923, Step 250, Total Reward: -4739.720211029053, Actor Loss: -3.3642864050165144e-09, Critic Loss: 0.0007410198450088501
# Episode 4924, Step 250, Total Reward: -5097.7828159332275, Actor Loss: 2.3003664251231015e-10, Critic Loss: 8.58306884765625e-06
# Episode 4925, Step 250, Total Reward: -5257.841079711914, Actor Loss: -1.5524263119459647e-07, Critic Loss: 1.6933023929595947
# Episode 4926, Step 250, Total Reward: -5173.853359222412, Actor Loss: -5.864595209459367e-07, Critic Loss: 24.192420959472656
# Episode 4927, Step 250, Total Reward: -3916.3796195983887, Actor Loss: -4.2481262951810095e-10, Critic Loss: 6.571412086486816e-06
# Episode 4928, Step 250, Total Reward: -4780.619215011597, Actor Loss: 2.7878942489624023, Critic Loss: 0.30443668365478516
# Episode 4929, Step 250, Total Reward: -4919.240287780762, Actor Loss: -2.2728927628890006e-09, Critic Loss: 0.00032639503479003906
# Episode 4930, Step 250, Total Reward: -5331.513008117676, Actor Loss: 0.02076875977218151, Critic Loss: 0.005187094211578369
# Episode 4931, Step 250, Total Reward: -4860.313522338867, Actor Loss: -50.1624641418457, Critic Loss: 9.90036392211914
# Episode 4932, Step 250, Total Reward: -4941.720497131348, Actor Loss: -1.6762642385259596e-09, Critic Loss: 0.00017060339450836182
# Episode 4933, Step 250, Total Reward: -4040.0397624969482, Actor Loss: 3.6060809893712076e-09, Critic Loss: 0.0009765625
# Episode 4934, Step 250, Total Reward: -4346.246392250061, Actor Loss: -1.01647920303094e-07, Critic Loss: 0.7253665924072266
# Episode 4935, Step 250, Total Reward: -4188.733093261719, Actor Loss: -1.3561356482227893e-09, Critic Loss: 0.00010766088962554932
# Episode 4936, Step 250, Total Reward: -5133.473373413086, Actor Loss: 8.437316623144397e-09, Critic Loss: 0.005151987075805664
# Episode 4937, Step 250, Total Reward: -5337.713661193848, Actor Loss: 1.39233886642387e-08, Critic Loss: 0.013876333832740784
# Episode 4938, Step 250, Total Reward: -3981.2937517166138, Actor Loss: 7.200386065164821e-09, Critic Loss: 0.0037701278924942017
# Episode 4939, Step 250, Total Reward: -5099.053779602051, Actor Loss: -1.5307450862422911e-09, Critic Loss: 0.0001402050256729126
# Episode 4940, Step 250, Total Reward: -4814.6300983428955, Actor Loss: 5.196335584045642e-10, Critic Loss: 2.8848648071289062e-05
# Episode 4941, Step 250, Total Reward: -4338.047336578369, Actor Loss: 1.175515329521204e-08, Critic Loss: 0.009922027587890625
# Episode 4942, Step 250, Total Reward: -5389.095675468445, Actor Loss: -6.723254131202339e-08, Critic Loss: 0.30403268337249756
# Episode 4943, Step 250, Total Reward: -5468.2668743133545, Actor Loss: 1.4272517889768466e-10, Critic Loss: 4.827976226806641e-06
# Episode 4944, Step 250, Total Reward: -4362.3802490234375, Actor Loss: -4.42657599464269e-09, Critic Loss: 0.0013055801391601562
# Episode 4945, Step 250, Total Reward: -5605.76024055481, Actor Loss: -1.7567913346283603e-07, Critic Loss: 2.1687164306640625
# Episode 4946, Step 250, Total Reward: -5100.786460876465, Actor Loss: 1.198798393886591e-08, Critic Loss: 0.01031494140625
# Episode 4947, Step 250, Total Reward: -5040.741958618164, Actor Loss: 3.669713777298966e-08, Critic Loss: 0.09538084268569946
# Episode 4948, Step 250, Total Reward: -4814.280479431152, Actor Loss: -4.4411279098710565e-09, Critic Loss: 0.001314416527748108
# Episode 4949, Step 250, Total Reward: -4710.213068008423, Actor Loss: 4.919711305007013e-10, Critic Loss: 2.6285648345947266e-05
# Episode 4950, Step 250, Total Reward: -4013.83261013031, Actor Loss: -32.80527114868164, Critic Loss: 4.234291076660156
# Episode 4951, Step 250, Total Reward: -4922.01756477356, Actor Loss: -1.0359799684778181e-09, Critic Loss: 5.914270877838135e-05
# Episode 4952, Step 250, Total Reward: -4800.577102661133, Actor Loss: 8.860090439100077e-10, Critic Loss: 7.940828800201416e-05
# Episode 4953, Step 250, Total Reward: -4645.719203948975, Actor Loss: 3.0240043802365335e-09, Critic Loss: 0.0006952285766601562
# Episode 4954, Step 250, Total Reward: -3254.3205490112305, Actor Loss: 9.802777290344238, Critic Loss: 8.975846290588379
# Episode 4955, Step 250, Total Reward: -4673.822732925415, Actor Loss: 1.7042792177512922e-10, Critic Loss: 5.9604644775390625e-06
# Episode 4956, Step 250, Total Reward: -5483.458393096924, Actor Loss: 59.65550231933594, Critic Loss: 14.002140045166016
# Episode 4957, Step 250, Total Reward: -4381.833366394043, Actor Loss: 1.597916687856582e-09, Critic Loss: 0.00020748376846313477
# Episode 4958, Step 250, Total Reward: -4080.4267053604126, Actor Loss: -7.174070781879038e-10, Critic Loss: 2.504885196685791e-05
# Episode 4959, Step 250, Total Reward: -4547.465702056885, Actor Loss: 9.576324178084406e-10, Critic Loss: 8.159875869750977e-05
# Episode 4960, Step 250, Total Reward: -4047.8598852157593, Actor Loss: 1.3650860442027124e-09, Critic Loss: 0.00015503168106079102
# Episode 4961, Step 250, Total Reward: -4305.17951965332, Actor Loss: 1.1613592310055765e-09, Critic Loss: 0.00011539459228515625
# Episode 4962, Step 250, Total Reward: -4977.539390563965, Actor Loss: -8.177014620969203e-10, Critic Loss: 3.4332275390625e-05
# Episode 4963, Step 250, Total Reward: -4419.290760040283, Actor Loss: -91.16856384277344, Critic Loss: 32.70270538330078
# Episode 4964, Step 250, Total Reward: -5071.213184356689, Actor Loss: -1.7053680689826933e-09, Critic Loss: 0.000177040696144104
# Episode 4965, Step 250, Total Reward: -5026.324005126953, Actor Loss: -4.8340296210369615e-09, Critic Loss: 0.0015642642974853516
# Episode 4966, Step 250, Total Reward: -5273.342475891113, Actor Loss: -26.793792724609375, Critic Loss: 2.824631690979004
# Episode 4967, Step 250, Total Reward: -5361.626968383789, Actor Loss: -13.908719062805176, Critic Loss: 0.7611454725265503
# Episode 4968, Step 250, Total Reward: -3585.45902633667, Actor Loss: -17.466175079345703, Critic Loss: 1.2002978324890137
# Episode 4969, Step 250, Total Reward: -4143.058010101318, Actor Loss: 2.2401231980495595e-09, Critic Loss: 0.0005379319190979004
# Episode 4970, Step 250, Total Reward: -5689.9147872924805, Actor Loss: -3.320630659331414e-09, Critic Loss: 0.0007212162017822266
# Episode 4971, Step 250, Total Reward: -4327.980224609375, Actor Loss: 3.853463770298049e-09, Critic Loss: 0.001110568642616272
# Episode 4972, Step 250, Total Reward: -5048.679644584656, Actor Loss: -1.1345715522766113, Critic Loss: 0.005064740777015686
# Episode 4973, Step 250, Total Reward: -5385.3160610198975, Actor Loss: 5.119480395165965e-09, Critic Loss: 0.0019311904907226562
# Episode 4974, Step 250, Total Reward: -5907.4894943237305, Actor Loss: -11.83613109588623, Critic Loss: 0.5512047410011292
# Episode 4975, Step 250, Total Reward: -3829.627317428589, Actor Loss: 1.8744030771955522e-09, Critic Loss: 0.00027967989444732666
# Episode 4976, Step 250, Total Reward: -5323.505706787109, Actor Loss: 1.8151108349684364e-07, Critic Loss: 2.3219778537750244
# Episode 4977, Step 250, Total Reward: -4878.8894691467285, Actor Loss: -1.1920934461784327e-08, Critic Loss: 0.009800806641578674
# Episode 4978, Step 250, Total Reward: -4734.186737060547, Actor Loss: -5.903303303966823e-07, Critic Loss: 24.512893676757812
# Episode 4979, Step 250, Total Reward: -4163.260149002075, Actor Loss: -0.030791567638516426, Critic Loss: 4.959211349487305
# Episode 4980, Step 250, Total Reward: -4735.614701271057, Actor Loss: -5.442696249247092e-08, Critic Loss: 0.20754075050354004
# Episode 4981, Step 250, Total Reward: -4858.053652763367, Actor Loss: 10.162491798400879, Critic Loss: 0.4063439965248108
# Episode 4982, Step 250, Total Reward: -3045.4204139709473, Actor Loss: 16.995220184326172, Critic Loss: 1.1364413499832153
# Episode 4983, Step 250, Total Reward: -4264.639984130859, Actor Loss: -5.412148507133452e-10, Critic Loss: 1.2531876564025879e-05
# Episode 4984, Step 250, Total Reward: -4322.46027469635, Actor Loss: -1.69083524959035e-09, Critic Loss: 0.00017380714416503906
# Episode 4985, Step 250, Total Reward: -3618.2816009521484, Actor Loss: 2.5914048684683166e-10, Critic Loss: 1.0073184967041016e-05
# Episode 4986, Step 250, Total Reward: -5064.926948547363, Actor Loss: -2.2781811992445e-09, Critic Loss: 0.00032639503479003906
# Episode 4987, Step 250, Total Reward: -4147.272557258606, Actor Loss: 2.1363375513061555e-09, Critic Loss: 0.00035800039768218994
# Episode 4988, Step 250, Total Reward: -5921.2799072265625, Actor Loss: -1.3894034811556821e-09, Critic Loss: 5.364418029785156e-07
# Episode 4989, Step 250, Total Reward: -4064.6703338623047, Actor Loss: -2.205516267395069e-07, Critic Loss: 3.4192488193511963
# Episode 4990, Step 250, Total Reward: -3993.4938135147095, Actor Loss: 7.2440600185075255e-09, Critic Loss: 0.0038152337074279785
# Episode 4991, Step 250, Total Reward: -3986.7064781188965, Actor Loss: 4.628673000439676e-10, Critic Loss: 2.384185791015625e-05
# Episode 4992, Step 250, Total Reward: -4860.220550537109, Actor Loss: 7.393536893829378e-10, Critic Loss: 5.187094211578369e-05
# Episode 4993, Step 250, Total Reward: -4696.656799316406, Actor Loss: -2.5348465548802324e-09, Critic Loss: 0.000410616397857666
# Episode 4994, Step 250, Total Reward: -5328.286666870117, Actor Loss: -2.2292370172039e-09, Critic Loss: 0.00031329691410064697
# Episode 4995, Step 250, Total Reward: -5623.013614654541, Actor Loss: -5.041063388944167e-08, Critic Loss: 0.177978515625
# Episode 4996, Step 250, Total Reward: -4525.840534210205, Actor Loss: -50.23641586303711, Critic Loss: 9.929576873779297
# Episode 4997, Step 250, Total Reward: -4920.162912368774, Actor Loss: -6.430782573119131e-10, Critic Loss: 1.9311904907226562e-05
# Episode 4998, Step 250, Total Reward: -4730.446595191956, Actor Loss: -0.10191400349140167, Critic Loss: 0.17205482721328735
# Episode 4999, Step 250, Total Reward: -5743.462942123413, Actor Loss: 6.688278517685831e-06, Critic Loss: 0.04347062110900879
# Episode 5000, Step 250, Total Reward: -4655.340084075928, Actor Loss: -50.250038146972656, Critic Loss: 9.934962272644043
# Training complete!
# Total reward on test set: -79916.8829536438
# Analysis of energy consumption before and after applying RL:
# Average energy consumption before RL: 98.02 Wh
# Average energy consumption after RL (estimated): 97.56 Wh
# Estimated energy savings: 0.48%
# Reinforcement learning process completed.

# %%
# Action Proability for lower number of episodes
'''
    This snippet is just to see how the action 
    probabilities change with the number of episodes.
'''
run_rl_process(X_train, y_train, X_test, y_test, scaler, data_test, episodes=10)
# Out:
# Episode 1, Step 250, Total Reward: -9699.519987106323, Actor Loss: -55.104286193847656, Critic Loss: 1658.31982421875
# Episode 2, Step 250, Total Reward: -18490.15316581726, Actor Loss: -138.73638916015625, Critic Loss: 7983.3662109375
# Episode 3, Step 250, Total Reward: -18634.773233413696, Actor Loss: -110.18389892578125, Critic Loss: 6310.5029296875
# Episode 4, Step 250, Total Reward: -20988.274968147278, Actor Loss: -50.62482833862305, Critic Loss: 14087.8525390625
# Episode 5, Step 250, Total Reward: -21856.259943008423, Actor Loss: -40.216068267822266, Critic Loss: 9467.0146484375
# Episode 6, Step 250, Total Reward: -22534.043312072754, Actor Loss: -32.16243362426758, Critic Loss: 3646.74755859375
# Episode 7, Step 250, Total Reward: -23150.556728363037, Actor Loss: -8.014039039611816, Critic Loss: 6475.96630859375
# Episode 8, Step 250, Total Reward: -21596.320079803467, Actor Loss: -41.687191009521484, Critic Loss: 1660.204345703125
# Episode 9, Step 250, Total Reward: -22679.903228759766, Actor Loss: -12.34658145904541, Critic Loss: 477.5761413574219
# Episode 10, Step 250, Total Reward: -22146.859951019287, Actor Loss: -0.00854366272687912, Critic Loss: 0.01763916015625
# Training complete!
# Total reward on test set: -307409.72998428345
# Analysis of energy consumption before and after applying RL:
# Average energy consumption before RL: 98.02 Wh
# Average energy consumption after RL (estimated): 101.99 Wh
# Estimated energy savings: -4.04%
# Reinforcement learning process completed.

# %% [markdown]
# #### Observations
#
# - We have purposelly taken small step size (200) for increasing iteration speed per episode.
# - After multiple hyper-parameter tuning, we have taken learning rate as 0.001, gamma as 0.99, tau as 0.01, and batch size as 32. This setup helped us get a savings of 0.48%.
# - For smaller step size and episodes we see variations however as we increase the episodes the probabilities tend to become 0 or 1.
