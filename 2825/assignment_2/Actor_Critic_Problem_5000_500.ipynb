# %% [markdown]
# ### Group ID: 134
# ### Group Members Name with Student ID:
#
# | Student Name       | Student ID    | Contribution |
# |--------------------|---------------|--------------|
# | Chakshu            | 2023aa05280   | 100%         |
# | Gali Jahnavi       | 2023aa05684   | 100%         |
# | Aashaank Pratap    | 2023aa05023   | 100%         |
# | Shivam Sahil       | 2023aa05663   | 100%         |

# %% [markdown]
# # Problem Statement
#
# The objective of the problem is to implement an Actor-Critic reinforcement learning algorithm to optimize energy consumption in a building. The agent should learn to adjust the temperature settings dynamically to minimize energy usage while maintaining comfortable indoor conditions.

# %% [markdown]
# #### Dataset Details
# Dataset: https://archive.ics.uci.edu/dataset/374/appliances+energy+prediction
#
# This dataset contains energy consumption data for a residential building, along with various environmental and operational factors.
#
# Data Dictionary:
# * Appliances:       Energy use in Wh
# * lights:           Energy use of light fixtures in the house in Wh
# * T1 - T9:          Temperatures in various rooms and outside
# * RH_1 to RH_9:     Humidity measurements in various rooms and outside
# * Visibility:       Visibility in km
# * Tdewpoint:       Dew point temperature
# * Pressure_mm_hgg:  Pressure in mm Hg
# * Windspeed:        Wind speed in m/s

# %% [markdown]
# #### Environment Details
# **State Space:**
# The state space consists of various features from the dataset that impact energy consumption and comfort levels.
#
# * Current Temperature (T1 to T9): Temperatures in various rooms and outside.
# * Current Humidity (RH_1 to RH_9): Humidity measurements in different locations.
# * Visibility (Visibility): Visibility in meters.
# * Dew Point (Tdewpoint): Dew point temperature.
# * Pressure (Press_mm_hg): Atmospheric pressure in mm Hg.
# * Windspeed (Windspeed): Wind speed in m/s.
#
# Total State Vector Dimension: Number of features = 9 (temperature) + 9 (humidity) + 1 (visibility) + 1 (dew point) + 1 (pressure) + 1 (windspeed) = 22 features
#
# **Target Variable:** Appliances (energy consumption in Wh).
#
# **Action Space:**
# The action space consists of discrete temperature adjustments:
# * Action 0: Decrease temperature by 1°C
# * Action 1: Maintain current temperature
# * Action 2: Increase temperature by 1°C
#
#
# - If the action is to decrease the temperature by 1°C, you'll adjust each temperature feature (T1 to T9) down by 1°C.
# - If the action is to increase the temperature by 1°C, you'll adjust each temperature feature (T1 to T9) up by 1°C.
# - Other features remain unchanged.
#
# **Policy (Actor):** A neural network that outputs a probability distribution over possible temperature adjustments.
#
# **Value function (Critic):** A neural network that estimates the expected cumulative reward (energy savings) from a given state.
#
# **Reward function:**
# The reward function should reflect the overall comfort and energy efficiency based on all temperature readings. i.e., balance between minimising temperature deviations and minimizing energy consumption.
#
# * Calculate the penalty based on the deviation of each temperature from the target temperature and then aggregate these penalties.
# * Measure the change in energy consumption before and after applying the RL action.
# * Combine the comfort penalty and energy savings to get the final reward.
#
# *Example:*
#
# Target temperature=22°C
#
# Initial Temperatures: T1=23, T2=22, T3=21, T4=23, T5=22, T6=21, T7=24, T8=22, T9=23
#
# Action Taken: Decrease temperature by 1°C for each room
#
# Resulting Temperatures: T1 = 22, T2 = 21, T3 = 20, T4 = 22, T5 = 21, T6 = 20, T7 = 23, T8 = 21, T9 = 22
#
# Energy Consumption: 50 Wh (before RL adjustment) and 48 Wh (after RL adjustment)
# * Energy Before (50 Wh): Use the energy consumption from the dataset at the current time step.
# * Energy After (48 Wh): Use the energy consumption from the dataset at the next time step (if available).
#
# Consider only temperature features for deviation calculation.
#
# Deviation = abs (Ti− Ttarget )
#
# Deviations=[ abs(22−22), abs(21−22), abs(20−22), abs(22−22),  abs(21−22), abs(20−22), abs(23−22), abs(21−22), abs(22−22) ]
#
# Deviations = [0, 1, 2, 0, 1, 2, 1, 1, 0], Sum of deviations = 8
#
# Energy Savings = Energy Before−Energy After = 50 – 48 = 2Wh
#
# Reward= −Sum of Deviations + Energy Savings = -8+6 = -2

# %% [markdown]
# #### Expected Outcomes
# 1. Pre-process the dataset to handle any missing values and create training and testing sets.
# 2. Implement the Actor-Critic algorithm using TensorFlow.
# 3. Train the model over 500 episodes to minimize energy consumption while maintaining an indoor temperature of 22°C.
# 4. Plot the total reward obtained in each episode to evaluate the learning progress.
# 5. Evaluate the performance of the model on test set to measure its performance
# 6. Provide graphs showing the convergence of the Actor and Critic losses.
# 7. Plot the learned policy by showing the action probabilities across different state values (e.g., temperature settings).
# 8. Provide an analysis on a comparison of the energy consumption before and after applying the reinforcement learning algorithm.

# %%
# Necessary Imports
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import warnings
import matplotlib.pyplot as plt

# %%
# file_path = 'https://raw.githubusercontent.com/sedhha/bits-ai-ml-practice-problems/main/2825/assignment_2/dataset/energydata_complete.csv'
# Load the dataset
file_path = r'dataset/energydata_complete.csv'
data = pd.read_csv(file_path)
data['date'] = pd.to_datetime(data['date'])

# Set 'date' as the index for time-based operations
data.set_index('date', inplace=True)

# Extract temporal features
data['hour'] = data.index.hour
data['day_of_week'] = data.index.dayofweek
data['month'] = data.index.month

# Handle missing values using time-aware methods
numeric_columns = data.select_dtypes(include=[np.number]).columns
data[numeric_columns] = data[numeric_columns].interpolate(method='time')
data[numeric_columns] = data[numeric_columns].fillna(method='bfill')

# Define features and target
features = ['T1', 'T2', 'T3', 'T4', 'T5', 'T6', 'T7', 'T8', 'T9',
            'RH_1', 'RH_2', 'RH_3', 'RH_4', 'RH_5', 'RH_6', 'RH_7', 'RH_8', 'RH_9',
            'Visibility', 'Tdewpoint', 'Press_mm_hg', 'Windspeed',
            'hour', 'day_of_week', 'month']
target = 'Appliances'

X = data[features]
y = data[target]

# Split the data without shuffling
split_index = int(len(X) * 0.8)
X_train, X_test = X[:split_index], X[split_index:]
y_train, y_test = y[:split_index], y[split_index:]
data_train, data_test = data.iloc[:split_index], data.iloc[split_index:]

# Reset indices to maintain consistency
X_train.reset_index(drop=True, inplace=True)
X_test.reset_index(drop=True, inplace=True)
y_train.reset_index(drop=True, inplace=True)
y_test.reset_index(drop=True, inplace=True)
data_train.reset_index(drop=True, inplace=True)
data_test.reset_index(drop=True, inplace=True)

# Fit scaler on training data only
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)

# Transform test data using the same scaler
X_test_scaled = scaler.transform(X_test)

# Convert scaled arrays back to DataFrames and set columns
X_train = pd.DataFrame(X_train_scaled, columns=features)
X_test = pd.DataFrame(X_test_scaled, columns=features)

print("Data preprocessing completed.")
print(f"Training set shape: {X_train.shape}")
print(f"Testing set shape: {X_test.shape}")

print(f"Length of X_train: {len(X_train)}")
print(f"Length of data_train: {len(data_train)}")
print(f"Length of y_train: {len(y_train)}")
# Out:
# Data preprocessing completed.
# Training set shape: (15788, 25)
# Testing set shape: (3947, 25)
# Length of X_train: 15788
# Length of data_train: 15788
# Length of y_train: 15788
# /var/folders/sb/2zyx_gr14m9cc4dd9p3l0d840000gp/T/ipykernel_12125/3041516445.py:18: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data[numeric_columns] = data[numeric_columns].fillna(method='bfill')

# %% [markdown]
# #### Defining Actor Critic Model using tensorflow (1 M)

# %%
# Define Actor and Critic models
class Actor(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(Actor, self).__init__()
        self.fc1 = nn.Linear(state_dim, 128)
        self.dropout1 = nn.Dropout(p=0.2)
        self.fc2 = nn.Linear(128, 64)
        self.dropout2 = nn.Dropout(p=0.2)
        self.fc3 = nn.Linear(64, action_dim)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = self.dropout1(x)
        x = torch.relu(self.fc2(x))
        x = self.dropout2(x)
        return torch.softmax(self.fc3(x), dim=-1)


class Critic(nn.Module):
    def __init__(self, state_dim):
        super(Critic, self).__init__()
        self.fc1 = nn.Linear(state_dim, 64)
        self.fc2 = nn.Linear(64, 64)
        self.fc3 = nn.Linear(64, 1)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.fc3(x)

# %% [markdown]
# ### Reward Function (0.5 M)

# %%
def calculate_reward(new_temps, energy_before, energy_after, action):
    target_temp = 22.0

    # Calculate deviations from target temperature
    deviations = [abs(temp - target_temp) for temp in new_temps]
    total_deviation = sum(deviations)

    # Calculate energy saved
    energy_saved = energy_before - energy_after  # Positive if energy consumption decreased

    # Scaling factors
    deviation_penalty_weight = 1.0
    energy_savings_scaling_factor = 3.0

    # Scale energy savings
    energy_savings_scaled = energy_saved * energy_savings_scaling_factor

    # Total reward
    reward = - (deviation_penalty_weight * total_deviation) + energy_savings_scaled

    return reward

# %% [markdown]
# #### Environment Simulation (0.5 M)

# %%
# Environment simulation
def simulate_environment(state, action, scaler, data, current_index):
    orig_state = scaler.inverse_transform(state.reshape(1, -1)).flatten()

    # Separate temperature and other features
    temps = orig_state[:9]
    other_features = orig_state[9:]

    # Apply action to temperatures
    temp_adjustment = [-1.0, 0.0, 1.0][action]  # Actions: Decrease, Maintain, Increase
    new_temps = temps + temp_adjustment
    new_temps = np.clip(new_temps, 10, 35)

    # Ensure current_index is valid
    if current_index >= len(data):
        current_index = len(data) - 1

    # Simulate energy consumption after action
    energy_before = data.iloc[current_index]['Appliances']

    # Energy change is symmetric for increase and decrease
    energy_sensitivity = 10  # Adjust this value as needed
    energy_change = temp_adjustment * energy_sensitivity

    energy_after = energy_before + energy_change

    # Construct next state
    next_state = np.concatenate([new_temps, other_features])
    next_state_scaled = scaler.transform(next_state.reshape(1, -1)).flatten()

    # Calculate reward
    reward = calculate_reward(new_temps, energy_before, energy_after, action)

    return next_state_scaled, reward

# %% [markdown]
# #### Implementation of Training Function (2 M)

# %%
# Training function
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

def train_function(X_train, y_train, state_dim, action_dim, scaler, data, episodes=500):
    warnings.filterwarnings("ignore", category=UserWarning, message="X does not have valid feature names, but StandardScaler was fitted with feature names")
    
    # Epsilon-greedy parameters
    epsilon_start = 1.0
    epsilon_end = 0.1
    epsilon_decay = episodes / 2

    # Entropy regularization coefficient
    entropy_coefficient = 0.001
    
    actor = Actor(state_dim, action_dim).to(device)
    critic = Critic(state_dim).to(device)
    actor_optimizer = optim.Adam(actor.parameters(), lr=0.0001)
    critic_optimizer = optim.Adam(critic.parameters(), lr=0.0005)

    actor_losses = []
    critic_losses = []
    episode_rewards = []
    for episode in range(episodes):
        # Start from a random state index
        state_index = np.random.randint(0, len(X_train) - 1)
        state = torch.FloatTensor(X_train.iloc[state_index].to_numpy()).to(device)
        total_reward = 0
        epsilon = epsilon_end + (epsilon_start - epsilon_end) * np.exp(-1. * episode / epsilon_decay)
        for step in range(5000):  # Limit steps per episode for faster training
            action_probs = actor(state)
            m = torch.distributions.Categorical(action_probs)

            # Epsilon-greedy action selection
            if np.random.rand() < epsilon:
                # Random action (exploration)
                action = torch.tensor([np.random.choice(action_dim)]).to(device)
            else:
                # Action according to policy (exploitation)
                action = m.sample()

            # Calculate entropy of the action distribution
            entropy = m.entropy()

            # Simulate environment
            current_index = state_index
            next_state, reward = simulate_environment(
                state.cpu().numpy(), action.item(), scaler, data_train, current_index)
            next_state = torch.FloatTensor(next_state).to(device)
            reward = torch.tensor([reward], dtype=torch.float32, device=device)

            # Compute critic values
            critic_value = critic(state)
            critic_value_next = critic(next_state)

            # Compute TD error (delta)
            delta = reward + 0.99 * critic_value_next - critic_value

            # Critic loss
            critic_loss = delta.pow(2).mean()

            # Actor loss with entropy regularization
            actor_loss = - (m.log_prob(action) * delta.detach() + entropy_coefficient * entropy)

            # Update Critic
            critic_optimizer.zero_grad()
            critic_loss.backward()
            torch.nn.utils.clip_grad_norm_(critic.parameters(), max_norm=1.0)
            critic_optimizer.step()

            # Update Actor
            actor_optimizer.zero_grad()
            actor_loss.backward()
            torch.nn.utils.clip_grad_norm_(actor.parameters(), max_norm=1.0)
            actor_optimizer.step()

            # Move to next state and index
            state = next_state
            state_index = (state_index + 1) % len(X_train)

            total_reward += reward.item()
            actor_losses.append(actor_loss.item())
            critic_losses.append(critic_loss.item())
            
            if (step + 1) % 100 == 0:
                print(f"Episode {episode + 1}, Step {step + 1}, Total Reward: {total_reward}, Actor Loss: {actor_loss.item()}, Critic Loss: {critic_loss.item()}")

        episode_rewards.append(total_reward)
    print("Training complete!")

    return actor, critic, episode_rewards, actor_losses, critic_losses
# Out:
# Using device: cpu

# %% [markdown]
# #### Evaluate the performance of the model on test set (0.5 M)

# %%
def evaluate_model(X_test, y_test, actor, scaler, data):
    total_reward = 0
    time_factor = 0
    state = torch.FloatTensor(X_test.iloc[0].values).to(device) # Start with the first state

    for step in range(len(X_test) - 1):
        # Predict action
        with torch.no_grad():
            action_probs = actor(state)
        action = torch.argmax(action_probs).item()

        # Simulate environment
        next_state, reward = simulate_environment(state.numpy(), action, scaler, data, step)

        total_reward += reward
        
        # Update state for the next iteration
        state = torch.FloatTensor(next_state)
        time_factor = (time_factor + 1) % 360  # Update time factor

    print(f"Total reward on test set: {total_reward}")
    return total_reward

# %% [markdown]
# ### Plot the convergence of Actor and Critic losses (1 M)

# %%
# Plots

# Plot the convergence of Actor and Critic losses
def plot_losses(actor_losses, critic_losses):
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(actor_losses)
    plt.title('Actor Loss')
    plt.xlabel('Training Step')
    plt.ylabel('Loss')

    plt.subplot(1, 2, 2)
    plt.plot(critic_losses)
    plt.title('Critic Loss')
    plt.xlabel('Training Step')
    plt.ylabel('Loss')

    plt.tight_layout()
    plt.show()

# Plot the learned policy
def plot_learned_policy(X_train, actor):
    states = torch.FloatTensor(X_train.iloc[:100].values).to(device)  # Use a subset of states for visualization
    with torch.no_grad():
        action_probs = actor(states)

    action_probs = action_probs.numpy()

    plt.figure(figsize=(10, 6))
    plt.plot(action_probs[:, 0], label='Decrease Temp')
    plt.plot(action_probs[:, 1], label='Maintain Temp')
    plt.plot(action_probs[:, 2], label='Increase Temp')
    plt.title('Action Probabilities Across Different States')
    plt.xlabel('State Index')
    plt.ylabel('Action Probability')
    plt.legend()
    plt.show()

def plot_episode_rewards(episode_rewards):
    plt.figure(figsize=(10, 6))
    plt.plot(episode_rewards)
    plt.title('Total Reward per Episode')
    plt.xlabel('Episode')
    plt.ylabel('Total Reward')
    plt.show()

# Conclusion and analysis
def analyze_results(y_train, y_test, episode_rewards):
    print("Analysis of energy consumption before and after applying RL:")
    print(f"Average energy consumption before RL: {y_train.mean():.2f} Wh")
    print(f"Average energy consumption after RL (estimated): {y_test.mean() - episode_rewards[-1]/len(y_test):.2f} Wh")
    print(f"Estimated energy savings: {(y_train.mean() - (y_test.mean() - episode_rewards[-1]/len(y_test))) / y_train.mean() * 100:.2f}%")

# %% [markdown]
# ### Plot the learned policy - by showing the action probabilities across different state values (1 M)

# %%
# Main execution
# Initiate training
def run_rl_process(X_train, y_train, X_test, y_test, state_dim, action_dim, scaler, data_train, data_test, episodes=500):
    # Train the model
    actor, critic, episode_rewards, actor_losses, critic_losses = train_function(
        X_train, y_train, state_dim, action_dim, scaler, data_train, episodes=episodes)

    # Evaluate the model
    test_reward = evaluate_model(X_test, y_test, actor, scaler, data_test)

    # Plot episode rewards
    plot_episode_rewards(episode_rewards)

    # Plot losses
    plot_losses(actor_losses, critic_losses)

    # Plot learned policy
    plot_learned_policy(X_train, actor)

    # Analyze results
    analyze_results(y_train, y_test, episode_rewards)

    print("Reinforcement learning process completed.")

# Main execution
state_dim = X_train.shape[1]
action_dim = 3

# Run the entire process
run_rl_process(X_train, y_train, X_test, y_test, state_dim, action_dim, scaler, data_train, data_test, episodes=500)
# Out:
# Episode 1, Step 100, Total Reward: -2862.717692375183, Actor Loss: -38.26301574707031, Critic Loss: 1092.589111328125
# Episode 1, Step 200, Total Reward: -7405.444274902344, Actor Loss: -42.31735610961914, Critic Loss: 1338.1297607421875
# Episode 1, Step 300, Total Reward: -11828.531017303467, Actor Loss: -159.8650360107422, Critic Loss: 16223.943359375
# Episode 1, Step 400, Total Reward: -19709.56098175049, Actor Loss: -158.48289489746094, Critic Loss: 5674.8779296875
# Episode 1, Step 500, Total Reward: -28577.56098175049, Actor Loss: -557.0174560546875, Critic Loss: 5158.58154296875
# Episode 1, Step 600, Total Reward: -37241.56098175049, Actor Loss: -502.7929382324219, Critic Loss: 9095.0478515625
# Episode 1, Step 700, Total Reward: -43829.56098175049, Actor Loss: -220.4266815185547, Critic Loss: 1260.012451171875
# Episode 1, Step 800, Total Reward: -46007.56098365784, Actor Loss: -2.275900260428898e-05, Critic Loss: 2.072321891784668
# Episode 1, Step 900, Total Reward: -51320.560901641846, Actor Loss: 6.90839224262163e-05, Critic Loss: 266.93365478515625
# Episode 1, Step 1000, Total Reward: -60956.56089782715, Actor Loss: -1118.8897705078125, Critic Loss: 4925.7001953125
# Episode 1, Step 1100, Total Reward: -67712.56089782715, Actor Loss: -2136.99560546875, Critic Loss: 17968.041015625
# Episode 1, Step 1200, Total Reward: -76091.56089782715, Actor Loss: -2199.396728515625, Critic Loss: 19032.70703125
# Episode 1, Step 1300, Total Reward: -87002.56089782715, Actor Loss: -2244.7060546875, Critic Loss: 19824.962890625
# Episode 1, Step 1400, Total Reward: -95228.56089782715, Actor Loss: -1055.8590087890625, Critic Loss: 4386.3701171875
# Episode 1, Step 1500, Total Reward: -105158.56089782715, Actor Loss: -1717.35986328125, Critic Loss: 11604.2236328125
# Episode 1, Step 1600, Total Reward: -111215.56089782715, Actor Loss: -1880.9892578125, Critic Loss: 13920.8603515625
# Episode 1, Step 1700, Total Reward: -118562.56089782715, Actor Loss: -2123.017822265625, Critic Loss: 17733.755859375
# Episode 1, Step 1800, Total Reward: -121073.56089782715, Actor Loss: -782.8402709960938, Critic Loss: 4278.09716796875
# Episode 1, Step 1900, Total Reward: -127070.56089782715, Actor Loss: 4.106667859105073e-07, Critic Loss: 11.874383926391602
# Episode 1, Step 2000, Total Reward: -128747.56089782715, Actor Loss: -99.45574188232422, Critic Loss: 186.28817749023438
# Episode 1, Step 2100, Total Reward: -136586.56090164185, Actor Loss: -461.5119934082031, Critic Loss: 10069.7744140625
# Episode 1, Step 2200, Total Reward: -143213.56093215942, Actor Loss: 99.25652313232422, Critic Loss: 38.762481689453125
# Episode 1, Step 2300, Total Reward: -146357.56090927124, Actor Loss: -2.1436584063394548e-07, Critic Loss: 3.2188968658447266
# Episode 1, Step 2400, Total Reward: -150992.56095314026, Actor Loss: -1.1911134834008408e-06, Critic Loss: 99.81575775146484
# Episode 1, Step 2500, Total Reward: -155834.5609779358, Actor Loss: -1056.4837646484375, Critic Loss: 4591.25341796875
# Episode 1, Step 2600, Total Reward: -164234.56098747253, Actor Loss: -900.9198608398438, Critic Loss: 3193.491455078125
# Episode 1, Step 2700, Total Reward: -170873.56100463867, Actor Loss: -998.3373413085938, Critic Loss: 3921.462646484375
# Episode 1, Step 2800, Total Reward: -179933.56100463867, Actor Loss: -1.4768196706427261e-05, Critic Loss: 15344.2294921875
# Episode 1, Step 2900, Total Reward: -188213.56100654602, Actor Loss: -1.6710870113456622e-05, Critic Loss: 19650.4140625
# Episode 1, Step 3000, Total Reward: -197594.56100654602, Actor Loss: 510.697021484375, Critic Loss: 1194.161376953125
# Episode 1, Step 3100, Total Reward: -201497.56104278564, Actor Loss: -506.5210266113281, Critic Loss: 1009.458251953125
# Episode 1, Step 3200, Total Reward: -205373.56097602844, Actor Loss: -920.8809204101562, Critic Loss: 3336.5712890625
# Episode 1, Step 3300, Total Reward: -210824.56096839905, Actor Loss: 1.0432851240693708e-06, Critic Loss: 76.63514709472656
# Episode 1, Step 3400, Total Reward: -214361.5609855652, Actor Loss: -0.013475509360432625, Critic Loss: 2941.87060546875
# Episode 1, Step 3500, Total Reward: -223244.5609855652, Actor Loss: -619.3203735351562, Critic Loss: 1509.1214599609375
# Episode 1, Step 3600, Total Reward: -228620.56103515625, Actor Loss: -910.9850463867188, Critic Loss: 3265.246337890625
# Episode 1, Step 3700, Total Reward: -234911.56105804443, Actor Loss: -0.13602153956890106, Critic Loss: 67.03115844726562
# Episode 1, Step 3800, Total Reward: -240956.56112098694, Actor Loss: -716.1034545898438, Critic Loss: 2017.6458740234375
# Episode 1, Step 3900, Total Reward: -249470.56112480164, Actor Loss: -1029.8485107421875, Critic Loss: 4172.92041015625
# Episode 1, Step 4000, Total Reward: -254690.56117248535, Actor Loss: 0.7508978843688965, Critic Loss: 55.3781623840332
# Episode 1, Step 4100, Total Reward: -261899.5611820221, Actor Loss: -0.018091561272740364, Critic Loss: 4029.831787109375
# Episode 1, Step 4200, Total Reward: -267656.5612182617, Actor Loss: -0.36747848987579346, Critic Loss: 115.00677490234375
# Episode 1, Step 4300, Total Reward: -273230.5612487793, Actor Loss: -659.8809204101562, Critic Loss: 1713.2646484375
# Episode 1, Step 4400, Total Reward: -280349.5612640381, Actor Loss: -760.7041015625, Critic Loss: 2276.799560546875
# Episode 1, Step 4500, Total Reward: -286403.5612850189, Actor Loss: -22.348770141601562, Critic Loss: 4.1101226806640625
# Episode 1, Step 4600, Total Reward: -289646.5613632202, Actor Loss: -411.89453125, Critic Loss: 1827.7294921875
# Episode 1, Step 4700, Total Reward: -293423.56131362915, Actor Loss: 2.318361759185791, Critic Loss: 40.96500015258789
# Episode 1, Step 4800, Total Reward: -296231.561416626, Actor Loss: 196.82339477539062, Critic Loss: 1533.7664794921875
# Episode 1, Step 4900, Total Reward: -300734.5614795685, Actor Loss: 51.28697967529297, Critic Loss: 438.5629577636719
# Episode 1, Step 5000, Total Reward: -302138.5615558624, Actor Loss: 6.15804386138916, Critic Loss: 83.05189514160156
# Episode 2, Step 100, Total Reward: -3526.6398601531982, Actor Loss: -627.4885864257812, Critic Loss: 2639.080322265625
# Episode 2, Step 200, Total Reward: -8719.799627304077, Actor Loss: -0.11474788933992386, Critic Loss: 75.24681091308594
# Episode 2, Step 300, Total Reward: -13429.0596408844, Actor Loss: -15.625099182128906, Critic Loss: 1818.0718994140625
# Episode 2, Step 400, Total Reward: -21081.27963066101, Actor Loss: -32.47636795043945, Critic Loss: 9721.1611328125
# Episode 2, Step 500, Total Reward: -27987.27968978882, Actor Loss: -520.6170654296875, Critic Loss: 21528.00390625
# Episode 2, Step 600, Total Reward: -35985.27970504761, Actor Loss: 1.5171912908554077, Critic Loss: 0.0758063793182373
# Episode 2, Step 700, Total Reward: -38418.27960586548, Actor Loss: -247.1959991455078, Critic Loss: 240.42315673828125
# Episode 2, Step 800, Total Reward: -41466.27965545654, Actor Loss: -2406.037109375, Critic Loss: 22777.080078125
# Episode 2, Step 900, Total Reward: -50262.27965545654, Actor Loss: -9.609677817934426e-07, Critic Loss: 64.96651458740234
# Episode 2, Step 1000, Total Reward: -57591.27966308594, Actor Loss: -1511.2314453125, Critic Loss: 14130.423828125
# Episode 2, Step 1100, Total Reward: -61629.27972793579, Actor Loss: 0.00013191650214139372, Critic Loss: 63.57006072998047
# Episode 2, Step 1200, Total Reward: -67941.27976036072, Actor Loss: -9.790556987354648e-07, Critic Loss: 67.43553161621094
# Episode 2, Step 1300, Total Reward: -76962.27976417542, Actor Loss: -261.3367919921875, Critic Loss: 268.71661376953125
# Episode 2, Step 1400, Total Reward: -80412.27983283997, Actor Loss: 0.005372830666601658, Critic Loss: 44.50495910644531
# Episode 2, Step 1500, Total Reward: -82395.279794693, Actor Loss: 0.06342427432537079, Critic Loss: 1.6387875080108643
# Episode 2, Step 1600, Total Reward: -84459.27983665466, Actor Loss: 2.694513625556283e-07, Critic Loss: 5.113715171813965
# Episode 2, Step 1700, Total Reward: -87138.27991867065, Actor Loss: 45.138877868652344, Critic Loss: 17.15488624572754
# Episode 2, Step 1800, Total Reward: -88725.27998924255, Actor Loss: -162.64395141601562, Critic Loss: 288.7883605957031
# Episode 2, Step 1900, Total Reward: -96012.27997016907, Actor Loss: -363.08819580078125, Critic Loss: 518.7017211914062
# Episode 2, Step 2000, Total Reward: -98073.27997016907, Actor Loss: 2.491894006729126, Critic Loss: 0.5654335021972656
# Episode 2, Step 2100, Total Reward: -103272.27997970581, Actor Loss: -296.2496643066406, Critic Loss: 345.3100280761719
# Episode 2, Step 2200, Total Reward: -111072.2799987793, Actor Loss: -2533.40673828125, Critic Loss: 25252.4375
# Episode 2, Step 2300, Total Reward: -118155.28002929688, Actor Loss: -2159.811767578125, Critic Loss: 18353.767578125
# Episode 2, Step 2400, Total Reward: -127581.28002929688, Actor Loss: 1.951671038114e-06, Critic Loss: 268.06866455078125
# Episode 2, Step 2500, Total Reward: -132705.2800617218, Actor Loss: -72.42964935302734, Critic Loss: 20.640783309936523
# Episode 2, Step 2600, Total Reward: -134406.28011131287, Actor Loss: -74.43350982666016, Critic Loss: 24.357213973999023
# Episode 2, Step 2700, Total Reward: -136119.28013038635, Actor Loss: 83.62957763671875, Critic Loss: 119.11942291259766
# Episode 2, Step 2800, Total Reward: -139614.28005981445, Actor Loss: 1.2156800721641048e-07, Critic Loss: 1.0434303283691406
# Episode 2, Step 2900, Total Reward: -143931.2799911499, Actor Loss: -1109.66552734375, Critic Loss: 4844.8193359375
# Episode 2, Step 3000, Total Reward: -145938.28003311157, Actor Loss: -2.096235220960807e-06, Critic Loss: 309.1793212890625
# Episode 2, Step 3100, Total Reward: -148623.28010177612, Actor Loss: -8.430825459981861e-07, Critic Loss: 50.00312805175781
# Episode 2, Step 3200, Total Reward: -151119.28013420105, Actor Loss: -789.7046508789062, Critic Loss: 2453.70751953125
# Episode 2, Step 3300, Total Reward: -159792.28007507324, Actor Loss: 4.6554200139325985e-07, Critic Loss: 15.2587890625
# Episode 2, Step 3400, Total Reward: -167115.28007507324, Actor Loss: -1299.0592041015625, Critic Loss: 6639.7431640625
# Episode 2, Step 3500, Total Reward: -175509.28007507324, Actor Loss: -1418.1988525390625, Critic Loss: 7913.48388671875
# Episode 2, Step 3600, Total Reward: -180645.28007507324, Actor Loss: -1006.5615234375, Critic Loss: 3986.337646484375
# Episode 2, Step 3700, Total Reward: -188868.28007507324, Actor Loss: 2.4578448574175127e-06, Critic Loss: 425.1388854980469
# Episode 2, Step 3800, Total Reward: -191982.28007507324, Actor Loss: 62.95198059082031, Critic Loss: 96.76007843017578
# Episode 2, Step 3900, Total Reward: -193125.28008270264, Actor Loss: 39.497825622558594, Critic Loss: 78.14715576171875
# Episode 2, Step 4000, Total Reward: -195258.28003501892, Actor Loss: 49.32918930053711, Critic Loss: 27.197141647338867
# Episode 2, Step 4100, Total Reward: -201036.2800140381, Actor Loss: -1517.492431640625, Critic Loss: 9060.380859375
# Episode 2, Step 4200, Total Reward: -211773.2800140381, Actor Loss: -2257.057861328125, Critic Loss: 20043.744140625
# Episode 2, Step 4300, Total Reward: -215070.28002166748, Actor Loss: -1.5183252799033653e-05, Critic Loss: 40.37957000732422
# Episode 2, Step 4400, Total Reward: -223167.2800064087, Actor Loss: -2.4505161491106264e-06, Critic Loss: 422.5252990722656
# Episode 2, Step 4500, Total Reward: -232851.2800064087, Actor Loss: -2.38246755657201e-07, Critic Loss: 3.9902403354644775
# Episode 2, Step 4600, Total Reward: -243165.2800064087, Actor Loss: 1.4934893215468037e-06, Critic Loss: 156.9832763671875
# Episode 2, Step 4700, Total Reward: -251778.2800064087, Actor Loss: -924.4014282226562, Critic Loss: 3362.131103515625
# Episode 2, Step 4800, Total Reward: -260034.2800064087, Actor Loss: -993.9898071289062, Critic Loss: 3887.382568359375
# Episode 2, Step 4900, Total Reward: -266535.2800064087, Actor Loss: 2.9650320357177407e-05, Critic Loss: 1719.69775390625
# Episode 2, Step 5000, Total Reward: -270855.2800273895, Actor Loss: -2.1403236871719855e-07, Critic Loss: 3.21999192237854
# Episode 3, Step 100, Total Reward: -3268.4600715637207, Actor Loss: -376.9210205078125, Critic Loss: 558.977294921875
# Episode 3, Step 200, Total Reward: -6835.513599395752, Actor Loss: -2929.54931640625, Critic Loss: 33767.203125
# Episode 3, Step 300, Total Reward: -11935.893339157104, Actor Loss: 1.6824036208618054e-07, Critic Loss: 1.9947423934936523
# Episode 3, Step 400, Total Reward: -17056.013496398926, Actor Loss: -4.103409992239904e-06, Critic Loss: 1184.7982177734375
# Episode 3, Step 500, Total Reward: -22415.014009475708, Actor Loss: -234.66754150390625, Critic Loss: 216.67034912109375
# Episode 3, Step 600, Total Reward: -32282.414335250854, Actor Loss: 4.026337592222262e-06, Critic Loss: 1140.843017578125
# Episode 3, Step 700, Total Reward: -35891.414335250854, Actor Loss: 35.723140716552734, Critic Loss: 1234.8292236328125
# Episode 3, Step 800, Total Reward: -39707.41435241699, Actor Loss: -563.9307250976562, Critic Loss: 1251.25244140625
# Episode 3, Step 900, Total Reward: -48095.41435241699, Actor Loss: -6.159562531138363e-07, Critic Loss: 26.68771743774414
# Episode 3, Step 1000, Total Reward: -56480.41435241699, Actor Loss: -242.52197265625, Critic Loss: 231.4171905517578
# Episode 3, Step 1100, Total Reward: -64706.41435241699, Actor Loss: -506.7545471191406, Critic Loss: 1010.3892822265625
# Episode 3, Step 1200, Total Reward: -74066.41435241699, Actor Loss: -430.7402038574219, Critic Loss: 730.0023193359375
# Episode 3, Step 1300, Total Reward: -82235.41435623169, Actor Loss: 211.13540649414062, Critic Loss: 175.3943328857422
# Episode 3, Step 1400, Total Reward: -88769.41439056396, Actor Loss: 64.3436508178711, Critic Loss: 3590.39697265625
# Episode 3, Step 1500, Total Reward: -93098.41445350647, Actor Loss: 1.513162351329811e-05, Critic Loss: 286.945068359375
# Episode 3, Step 1600, Total Reward: -95423.41442871094, Actor Loss: 89.41372680664062, Critic Loss: 628.1778564453125
# Episode 3, Step 1700, Total Reward: -97277.41451454163, Actor Loss: -174.0355224609375, Critic Loss: 140.2281494140625
# Episode 3, Step 1800, Total Reward: -106151.41451644897, Actor Loss: 4.027556769869989e-06, Critic Loss: 1141.5357666015625
# Episode 3, Step 1900, Total Reward: -114533.41451835632, Actor Loss: -915.5505981445312, Critic Loss: 3298.056884765625
# Episode 3, Step 2000, Total Reward: -120299.41452980042, Actor Loss: 183.41766357421875, Critic Loss: 3485.783935546875
# Episode 3, Step 2100, Total Reward: -125903.41458129883, Actor Loss: -2.299612788192462e-06, Critic Loss: 372.0867614746094
# Episode 3, Step 2200, Total Reward: -131408.41459465027, Actor Loss: 128.1009063720703, Critic Loss: 850.2293090820312
# Episode 3, Step 2300, Total Reward: -132569.4146308899, Actor Loss: 61.554176330566406, Critic Loss: 918.8180541992188
# Episode 3, Step 2400, Total Reward: -138203.41457557678, Actor Loss: 0.00010879943147301674, Critic Loss: 14.373650550842285
# Episode 3, Step 2500, Total Reward: -142865.4144935608, Actor Loss: 7.713086233707145e-05, Critic Loss: 0.5371572971343994
# Episode 3, Step 2600, Total Reward: -144509.4145450592, Actor Loss: -152.0791015625, Critic Loss: 132.59275817871094
# Episode 3, Step 2700, Total Reward: -151103.4145679474, Actor Loss: 0.20953164994716644, Critic Loss: 1636.020751953125
# Episode 3, Step 2800, Total Reward: -155540.41473007202, Actor Loss: 42.184043884277344, Critic Loss: 23.1695556640625
# Episode 3, Step 2900, Total Reward: -163535.4146709442, Actor Loss: -1.3806752576783765e-06, Critic Loss: 134.052978515625
# Episode 3, Step 3000, Total Reward: -170762.4146709442, Actor Loss: -2.748374527072883e-06, Critic Loss: 531.2259521484375
# Episode 3, Step 3100, Total Reward: -175007.4146709442, Actor Loss: 112.41693115234375, Critic Loss: 587.32861328125
# Episode 3, Step 3200, Total Reward: -177113.41471481323, Actor Loss: 10.517560005187988, Critic Loss: 295.56964111328125
# Episode 3, Step 3300, Total Reward: -185759.41466140747, Actor Loss: -1053.100341796875, Critic Loss: 4363.47998046875
# Episode 3, Step 3400, Total Reward: -195044.41466140747, Actor Loss: 1.4430224837269634e-06, Critic Loss: 146.55419921875
# Episode 3, Step 3500, Total Reward: -203696.41466140747, Actor Loss: -729.6988525390625, Critic Loss: 2094.984130859375
# Episode 3, Step 3600, Total Reward: -213716.41466140747, Actor Loss: -453.3382263183594, Critic Loss: 808.6080932617188
# Episode 3, Step 3700, Total Reward: -222209.41466140747, Actor Loss: -795.4923095703125, Critic Loss: 2489.805419921875
# Episode 3, Step 3800, Total Reward: -229793.41466140747, Actor Loss: 101.04182434082031, Critic Loss: 2333.389892578125
# Episode 3, Step 3900, Total Reward: -235700.41468048096, Actor Loss: -1.4528912117839354e-07, Critic Loss: 1.4829721450805664
# Episode 3, Step 4000, Total Reward: -241853.4147090912, Actor Loss: 2.4405477046966553, Critic Loss: 3368.022705078125
# Episode 3, Step 4100, Total Reward: -246482.4147758484, Actor Loss: -1313.814453125, Critic Loss: 6791.43408203125
# Episode 3, Step 4200, Total Reward: -251201.41479110718, Actor Loss: -294.4407958984375, Critic Loss: 659.5968017578125
# Episode 3, Step 4300, Total Reward: -255389.41486167908, Actor Loss: 33.86497497558594, Critic Loss: 32.28104019165039
# Episode 3, Step 4400, Total Reward: -258020.41521263123, Actor Loss: -180.46896362304688, Critic Loss: 133.9286346435547
# Episode 3, Step 4500, Total Reward: -261440.41531562805, Actor Loss: 46.62800979614258, Critic Loss: 22.202133178710938
# Episode 3, Step 4600, Total Reward: -264680.4152355194, Actor Loss: 2.88952898979187, Critic Loss: 985.5552978515625
# Episode 3, Step 4700, Total Reward: -269351.41530799866, Actor Loss: -588.1790161132812, Critic Loss: 1361.17041015625
# Episode 3, Step 4800, Total Reward: -276500.41532707214, Actor Loss: -506.6144104003906, Critic Loss: 1009.8306274414062
# Episode 3, Step 4900, Total Reward: -284063.41533851624, Actor Loss: -620.5075073242188, Critic Loss: 1514.912353515625
# Episode 3, Step 5000, Total Reward: -292223.41534233093, Actor Loss: -467.0464782714844, Critic Loss: 858.2496948242188
# Episode 4, Step 100, Total Reward: -5933.229921340942, Actor Loss: -2.6250518203596584e-06, Critic Loss: 484.8597412109375
# Episode 4, Step 200, Total Reward: -11939.229963302612, Actor Loss: 6.175645351409912, Critic Loss: 1200.37890625
# Episode 4, Step 300, Total Reward: -16946.229904174805, Actor Loss: 0.00623431196436286, Critic Loss: 1625.1763916015625
# Episode 4, Step 400, Total Reward: -26768.22989845276, Actor Loss: -740.947265625, Critic Loss: 2160.07080078125
# Episode 4, Step 500, Total Reward: -30599.22989845276, Actor Loss: 9.675030742073432e-05, Critic Loss: 98.21119689941406
# Episode 4, Step 600, Total Reward: -33638.22989845276, Actor Loss: 18.742700576782227, Critic Loss: 1251.52880859375
# Episode 4, Step 700, Total Reward: -39482.22989845276, Actor Loss: -1100.46826171875, Critic Loss: 4764.841796875
# Episode 4, Step 800, Total Reward: -46661.22989845276, Actor Loss: -404.60028076171875, Critic Loss: 644.0888671875
# Episode 4, Step 900, Total Reward: -57386.22989845276, Actor Loss: -2.514016728127899e-07, Critic Loss: 4.44328498840332
# Episode 4, Step 1000, Total Reward: -67253.22989845276, Actor Loss: 6.50700656024128e-07, Critic Loss: 29.80584144592285
# Episode 4, Step 1100, Total Reward: -72656.22989845276, Actor Loss: 456.8291015625, Critic Loss: 5132.16943359375
# Episode 4, Step 1200, Total Reward: -78125.22994422913, Actor Loss: -477.1038818359375, Critic Loss: 895.61083984375
# Episode 4, Step 1300, Total Reward: -85679.22994613647, Actor Loss: -220.3287353515625, Critic Loss: 191.00103759765625
# Episode 4, Step 1400, Total Reward: -90248.23001289368, Actor Loss: 1.231621503829956, Critic Loss: 1430.70849609375
# Episode 4, Step 1500, Total Reward: -92189.23002052307, Actor Loss: 16.241003036499023, Critic Loss: 1539.5277099609375
# Episode 4, Step 1600, Total Reward: -93824.23007774353, Actor Loss: 60.257301330566406, Critic Loss: 1843.9224853515625
# Episode 4, Step 1700, Total Reward: -98624.23013114929, Actor Loss: -1123.572265625, Critic Loss: 4967.0146484375
# Episode 4, Step 1800, Total Reward: -105530.23015594482, Actor Loss: 24.7138729095459, Critic Loss: 2328.81640625
# Episode 4, Step 1900, Total Reward: -109133.23013496399, Actor Loss: 72.93577575683594, Critic Loss: 272.185546875
# Episode 4, Step 2000, Total Reward: -115877.23016166687, Actor Loss: -1.3088611012790352e-06, Critic Loss: 120.52780151367188
# Episode 4, Step 2100, Total Reward: -123755.23016548157, Actor Loss: -575.4437866210938, Critic Loss: 1302.864501953125
# Episode 4, Step 2200, Total Reward: -132254.23016548157, Actor Loss: -809.8700561523438, Critic Loss: 2580.6201171875
# Episode 4, Step 2300, Total Reward: -140918.23016738892, Actor Loss: 5.405717615758476e-07, Critic Loss: 20.572071075439453
# Episode 4, Step 2400, Total Reward: -149663.23016929626, Actor Loss: 89.87052154541016, Critic Loss: 31.77810287475586
# Episode 4, Step 2500, Total Reward: -156317.2302494049, Actor Loss: 1.3603409570350777e-05, Critic Loss: 40.37336730957031
# Episode 4, Step 2600, Total Reward: -164771.2302722931, Actor Loss: -436.7652893066406, Critic Loss: 750.5673828125
# Episode 4, Step 2700, Total Reward: -171677.23029518127, Actor Loss: 1.578469164087437e-05, Critic Loss: 41.9015998840332
# Episode 4, Step 2800, Total Reward: -180242.23029518127, Actor Loss: 0.011639777570962906, Critic Loss: 1653.4071044921875
# Episode 4, Step 2900, Total Reward: -181985.23030090332, Actor Loss: -43.476173400878906, Critic Loss: 18.16640853881836
# Episode 4, Step 3000, Total Reward: -190286.23030090332, Actor Loss: -500.4881286621094, Critic Loss: 985.5552978515625
# Episode 4, Step 3100, Total Reward: -199226.23030281067, Actor Loss: 11.594706535339355, Critic Loss: 1.82672119140625
# Episode 4, Step 3200, Total Reward: -202361.23030662537, Actor Loss: 8.960132598876953, Critic Loss: 2420.4189453125
# Episode 4, Step 3300, Total Reward: -208640.230386734, Actor Loss: -271.3319091796875, Critic Loss: 289.6644287109375
# Episode 4, Step 3400, Total Reward: -214841.23045539856, Actor Loss: 61.03407669067383, Critic Loss: 2873.912841796875
# Episode 4, Step 3500, Total Reward: -216647.23045921326, Actor Loss: 69.18021392822266, Critic Loss: 4475.8583984375
# Episode 4, Step 3600, Total Reward: -222563.2304019928, Actor Loss: -127.13946533203125, Critic Loss: 98.54051971435547
# Episode 4, Step 3700, Total Reward: -226082.23030281067, Actor Loss: 32.328365325927734, Critic Loss: 134.21131896972656
# Episode 4, Step 3800, Total Reward: -229271.2303390503, Actor Loss: -204.7947998046875, Critic Loss: 232.0117950439453
# Episode 4, Step 3900, Total Reward: -233357.230386734, Actor Loss: 43.51497268676758, Critic Loss: 92.60302734375
# Episode 4, Step 4000, Total Reward: -241694.23039627075, Actor Loss: 32.80678939819336, Critic Loss: 506.25
# Episode 4, Step 4100, Total Reward: -247280.2303981781, Actor Loss: 44.301822662353516, Critic Loss: 937.2327880859375
# Episode 4, Step 4200, Total Reward: -250442.2303466797, Actor Loss: -359.186279296875, Critic Loss: 507.61322021484375
# Episode 4, Step 4300, Total Reward: -255227.23038101196, Actor Loss: -1.880808326859551e-07, Critic Loss: 0.08959031105041504
# Episode 4, Step 4400, Total Reward: -260171.2304096222, Actor Loss: -0.002682704711332917, Critic Loss: 7209.361328125
# Episode 4, Step 4500, Total Reward: -265172.2304325104, Actor Loss: -2.0874483652733034e-06, Critic Loss: 306.5918884277344
# Episode 4, Step 4600, Total Reward: -268415.2304611206, Actor Loss: 16.318403244018555, Critic Loss: 140.30911254882812
# Episode 4, Step 4700, Total Reward: -270986.2303943634, Actor Loss: 23.990711212158203, Critic Loss: 2017.711669921875
# Episode 4, Step 4800, Total Reward: -274739.23046684265, Actor Loss: -617.2575073242188, Critic Loss: 1499.0848388671875
# Episode 4, Step 4900, Total Reward: -278285.2305469513, Actor Loss: -891.58642578125, Critic Loss: 3127.665771484375
# Episode 4, Step 5000, Total Reward: -286757.2305469513, Actor Loss: 0.28769779205322266, Critic Loss: 2496.11962890625
# Episode 5, Step 100, Total Reward: -3380.3134593963623, Actor Loss: -74.1024398803711, Critic Loss: 49.63436508178711
# Episode 5, Step 200, Total Reward: -12651.459980010986, Actor Loss: 0.21086445450782776, Critic Loss: 3959.223876953125
# Episode 5, Step 300, Total Reward: -15459.459980010986, Actor Loss: 147.5851287841797, Critic Loss: 591.3232421875
# Episode 5, Step 400, Total Reward: -18531.460048675537, Actor Loss: -282.26666259765625, Critic Loss: 318.8787841796875
# Episode 5, Step 500, Total Reward: -23232.460103988647, Actor Loss: -9.490144634582975e-07, Critic Loss: 63.32600402832031
# Episode 5, Step 600, Total Reward: -31758.460109710693, Actor Loss: 2.12230679608183e-06, Critic Loss: 316.989501953125
# Episode 5, Step 700, Total Reward: -37893.460220336914, Actor Loss: 0.2836168110370636, Critic Loss: 642.5779418945312
# Episode 5, Step 800, Total Reward: -40914.460262298584, Actor Loss: -134.19471740722656, Critic Loss: 70.8539810180664
# Episode 5, Step 900, Total Reward: -42720.46020317078, Actor Loss: -83.45610046386719, Critic Loss: 241.37142944335938
# Episode 5, Step 1000, Total Reward: -49440.4602355957, Actor Loss: -812.3999633789062, Critic Loss: 2596.768310546875
# Episode 5, Step 1100, Total Reward: -54498.460260391235, Actor Loss: 52.860809326171875, Critic Loss: 1233.834228515625
# Episode 5, Step 1200, Total Reward: -58008.46026992798, Actor Loss: 0.4574277997016907, Critic Loss: 1047.5400390625
# Episode 5, Step 1300, Total Reward: -60735.460330963135, Actor Loss: 44.41097640991211, Critic Loss: 756.7468872070312
# Episode 5, Step 1400, Total Reward: -63720.46028137207, Actor Loss: -103.96500396728516, Critic Loss: 542.118896484375
# Episode 5, Step 1500, Total Reward: -67620.46019172668, Actor Loss: 26.971824645996094, Critic Loss: 275.9848937988281
# Episode 5, Step 1600, Total Reward: -71298.46026802063, Actor Loss: 23.912193298339844, Critic Loss: 2030.2108154296875
# Episode 5, Step 1700, Total Reward: -73815.46024894714, Actor Loss: -96.08592987060547, Critic Loss: 113.23329162597656
# Episode 5, Step 1800, Total Reward: -83958.46022605896, Actor Loss: -1.0086851034429856e-06, Critic Loss: 71.5792007446289
# Episode 5, Step 1900, Total Reward: -87633.46022605896, Actor Loss: -1.5479905605316162, Critic Loss: 0.013278961181640625
# Episode 5, Step 2000, Total Reward: -89667.46022987366, Actor Loss: -524.0708618164062, Critic Loss: 1080.6212158203125
# Episode 5, Step 2100, Total Reward: -98727.46022987366, Actor Loss: -8.578672918702068e-07, Critic Loss: 51.77252197265625
# Episode 5, Step 2200, Total Reward: -105741.4602355957, Actor Loss: -0.01600499264895916, Critic Loss: 27.94061851501465
# Episode 5, Step 2300, Total Reward: -108042.46026229858, Actor Loss: -321.3597412109375, Critic Loss: 1149.81591796875
# Episode 5, Step 2400, Total Reward: -112614.46020507812, Actor Loss: 40.7149543762207, Critic Loss: 275.3282470703125
# Episode 5, Step 2500, Total Reward: -120792.46022033691, Actor Loss: -1504.4146728515625, Critic Loss: 8904.8896484375
# Episode 5, Step 2600, Total Reward: -129066.460231781, Actor Loss: -9.490786965216103e-07, Critic Loss: 63.368751525878906
# Episode 5, Step 2700, Total Reward: -133740.46030426025, Actor Loss: 35.51166915893555, Critic Loss: 2141.682861328125
# Episode 5, Step 2800, Total Reward: -136689.46033287048, Actor Loss: -817.5843505859375, Critic Loss: 2630.01708984375
# Episode 5, Step 2900, Total Reward: -145257.46034431458, Actor Loss: 43.43849563598633, Critic Loss: 8.32187271118164
# Episode 5, Step 3000, Total Reward: -149736.46040344238, Actor Loss: -1002.2451171875, Critic Loss: 3952.221923828125
# Episode 5, Step 3100, Total Reward: -154617.46046447754, Actor Loss: -15.653776168823242, Critic Loss: 2.6980628967285156
# Episode 5, Step 3200, Total Reward: -158241.4605140686, Actor Loss: 33.33226776123047, Critic Loss: 177.82118225097656
# Episode 5, Step 3300, Total Reward: -162978.4605369568, Actor Loss: -589.6502685546875, Critic Loss: 1367.988525390625
# Episode 5, Step 3400, Total Reward: -166278.46061897278, Actor Loss: 0.13660931587219238, Critic Loss: 5.594333648681641
# Episode 5, Step 3500, Total Reward: -167796.46071624756, Actor Loss: -121.71700286865234, Critic Loss: 166.93699645996094
# Episode 5, Step 3600, Total Reward: -173289.4606742859, Actor Loss: -1344.21240234375, Critic Loss: 7109.3388671875
# Episode 5, Step 3700, Total Reward: -183087.4606742859, Actor Loss: -999.3181762695312, Critic Loss: 3929.171630859375
# Episode 5, Step 3800, Total Reward: -192054.4606742859, Actor Loss: -1529.1689453125, Critic Loss: 9200.3505859375
# Episode 5, Step 3900, Total Reward: -200091.4606742859, Actor Loss: -752.2501220703125, Critic Loss: 2226.475830078125
# Episode 5, Step 4000, Total Reward: -203451.4606742859, Actor Loss: -337.0250244140625, Critic Loss: 559.2947998046875
# Episode 5, Step 4100, Total Reward: -208281.4606742859, Actor Loss: -188.74996948242188, Critic Loss: 236.51075744628906
# Episode 5, Step 4200, Total Reward: -213861.4606742859, Actor Loss: 84.19640350341797, Critic Loss: 574.5477905273438
# Episode 5, Step 4300, Total Reward: -216207.4606742859, Actor Loss: 65.24114227294922, Critic Loss: 814.8961791992188
# Episode 5, Step 4400, Total Reward: -220929.4606742859, Actor Loss: 9.865835189819336, Critic Loss: 0.8085065484046936
# Episode 5, Step 4500, Total Reward: -224685.4606742859, Actor Loss: -8.210382657125592e-05, Critic Loss: 108.62565612792969
# Episode 5, Step 4600, Total Reward: -226233.4606781006, Actor Loss: -475.8544921875, Critic Loss: 890.9263305664062
# Episode 5, Step 4700, Total Reward: -231465.4607143402, Actor Loss: -3.118452696071472e-06, Critic Loss: 684.2643432617188
# Episode 5, Step 4800, Total Reward: -238704.46066856384, Actor Loss: -1152.5767822265625, Critic Loss: 5226.767578125
# Episode 5, Step 4900, Total Reward: -244551.46056747437, Actor Loss: -4.53612574347062e-06, Critic Loss: 1447.8619384765625
# Episode 5, Step 5000, Total Reward: -248994.46049308777, Actor Loss: 0.03572647273540497, Critic Loss: 1380.8409423828125
# Episode 6, Step 100, Total Reward: -3353.266803741455, Actor Loss: 20.59073257446289, Critic Loss: 197.4862060546875
# Episode 6, Step 200, Total Reward: -5708.080310821533, Actor Loss: -398.65692138671875, Critic Loss: 625.3052368164062
# Episode 6, Step 300, Total Reward: -13495.837171554565, Actor Loss: -1353.2850341796875, Critic Loss: 7205.630859375
# Episode 6, Step 400, Total Reward: -19546.837203979492, Actor Loss: -295.1092529296875, Critic Loss: 342.6566162109375
# Episode 6, Step 500, Total Reward: -25825.837266921997, Actor Loss: -1041.29931640625, Critic Loss: 4266.23291015625
# Episode 6, Step 600, Total Reward: -35026.837266922, Actor Loss: -464.6800231933594, Critic Loss: 849.574462890625
# Episode 6, Step 700, Total Reward: -41353.83730697632, Actor Loss: 140.8036346435547, Critic Loss: 78.00477600097656
# Episode 6, Step 800, Total Reward: -47443.837451934814, Actor Loss: -66.05814361572266, Critic Loss: 17.169044494628906
# Episode 6, Step 900, Total Reward: -49246.837493896484, Actor Loss: 19.968475341796875, Critic Loss: 960.6669921875
# Episode 6, Step 1000, Total Reward: -50728.837564468384, Actor Loss: -2.1292098608682863e-06, Critic Loss: 318.9834289550781
# Episode 6, Step 1100, Total Reward: -53947.83765029907, Actor Loss: 8.614450454711914, Critic Loss: 970.9705810546875
# Episode 6, Step 1200, Total Reward: -57838.837728500366, Actor Loss: -732.8515014648438, Critic Loss: 2113.1259765625
# Episode 6, Step 1300, Total Reward: -61939.83778953552, Actor Loss: 2.0162389091638033e-08, Critic Loss: 0.029039621353149414
# Episode 6, Step 1400, Total Reward: -68263.83782196045, Actor Loss: -1072.164306640625, Critic Loss: 4522.89111328125
# Episode 6, Step 1500, Total Reward: -75472.83783912659, Actor Loss: -1.7337180224785698e-06, Critic Loss: 211.48373413085938
# Episode 6, Step 1600, Total Reward: -81364.83779525757, Actor Loss: 1.0002229373640148e-06, Critic Loss: 70.41897583007812
# Episode 6, Step 1700, Total Reward: -87292.83773422241, Actor Loss: -1114.6202392578125, Critic Loss: 4888.18115234375
# Episode 6, Step 1800, Total Reward: -90247.83770370483, Actor Loss: -9.20149489047617e-07, Critic Loss: 59.56402587890625
# Episode 6, Step 1900, Total Reward: -92458.83777999878, Actor Loss: 19.73563575744629, Critic Loss: 34.32941436767578
# Episode 6, Step 2000, Total Reward: -95896.83786582947, Actor Loss: -3.0337166663230164e-06, Critic Loss: 647.5757446289062
# Episode 6, Step 2100, Total Reward: -102322.8378982544, Actor Loss: 96.17132568359375, Critic Loss: 3061.7958984375
# Episode 6, Step 2200, Total Reward: -105946.83795166016, Actor Loss: -682.233642578125, Critic Loss: 1831.3009033203125
# Episode 6, Step 2300, Total Reward: -113902.83795166016, Actor Loss: -604.2381591796875, Critic Loss: 1436.513671875
# Episode 6, Step 2400, Total Reward: -118801.83798408508, Actor Loss: 47.528350830078125, Critic Loss: 335.920166015625
# Episode 6, Step 2500, Total Reward: -125665.83790206909, Actor Loss: -794.647705078125, Critic Loss: 2484.52099609375
# Episode 6, Step 2600, Total Reward: -127699.83784866333, Actor Loss: 0.6817280650138855, Critic Loss: 282.4960021972656
# Episode 6, Step 2700, Total Reward: -130561.83787727356, Actor Loss: -1443.2567138671875, Critic Loss: 8195.59765625
# Episode 6, Step 2800, Total Reward: -136750.83787727356, Actor Loss: 80.49684143066406, Critic Loss: 301.17840576171875
# Episode 6, Step 2900, Total Reward: -140536.8379020691, Actor Loss: -289.31768798828125, Critic Loss: 329.3392028808594
# Episode 6, Step 3000, Total Reward: -145300.83788871765, Actor Loss: 27.584707260131836, Critic Loss: 670.5520629882812
# Episode 6, Step 3100, Total Reward: -147373.83789253235, Actor Loss: -231.9624786376953, Critic Loss: 211.70391845703125
# Episode 6, Step 3200, Total Reward: -152893.8378047943, Actor Loss: 1.9353667084942572e-05, Critic Loss: 538.6796264648438
# Episode 6, Step 3300, Total Reward: -157549.8378238678, Actor Loss: -718.711181640625, Critic Loss: 2032.3675537109375
# Episode 6, Step 3400, Total Reward: -166867.8378238678, Actor Loss: 8.230284009869138e-08, Critic Loss: 0.4780426025390625
# Episode 6, Step 3500, Total Reward: -173179.83785820007, Actor Loss: 5.5643731400323304e-08, Critic Loss: 0.2188119888305664
# Episode 6, Step 3600, Total Reward: -181078.83786392212, Actor Loss: -431.21502685546875, Critic Loss: 731.6126708984375
# Episode 6, Step 3700, Total Reward: -189367.83787345886, Actor Loss: -154.95562744140625, Critic Loss: 94.47308349609375
# Episode 6, Step 3800, Total Reward: -197095.8378791809, Actor Loss: -733.5988159179688, Critic Loss: 2117.437744140625
# Episode 6, Step 3900, Total Reward: -205957.83788108826, Actor Loss: -132.91029357910156, Critic Loss: 69.50413513183594
# Episode 6, Step 4000, Total Reward: -211093.8378982544, Actor Loss: 99.32777404785156, Critic Loss: 986.3218994140625
# Episode 6, Step 4100, Total Reward: -215071.83815574646, Actor Loss: 78.91874694824219, Critic Loss: 697.4447631835938
# Episode 6, Step 4200, Total Reward: -218761.83815193176, Actor Loss: 119.40145111083984, Critic Loss: 368.8162841796875
# Episode 6, Step 4300, Total Reward: -220123.838224411, Actor Loss: 75.63870239257812, Critic Loss: 129.390625
# Episode 6, Step 4400, Total Reward: -223852.8381652832, Actor Loss: -0.000578603649046272, Critic Loss: 266.69537353515625
# Episode 6, Step 4500, Total Reward: -227644.838180542, Actor Loss: -4.034639914607396e-06, Critic Loss: 1145.4158935546875
# Episode 6, Step 4600, Total Reward: -230119.83827209473, Actor Loss: 25.294065475463867, Critic Loss: 58.13690185546875
# Episode 6, Step 4700, Total Reward: -236080.838224411, Actor Loss: -1343.6285400390625, Critic Loss: 7103.16455078125
# Episode 6, Step 4800, Total Reward: -245944.8382205963, Actor Loss: -1501.4215087890625, Critic Loss: 8869.4912109375
# Episode 6, Step 4900, Total Reward: -254227.8382205963, Actor Loss: -1.0291724947819603e-06, Critic Loss: 74.51702117919922
# Episode 6, Step 5000, Total Reward: -261751.8382205963, Actor Loss: 2.0056004359503277e-06, Critic Loss: 283.0871887207031
# Episode 7, Step 100, Total Reward: -2747.184757232666, Actor Loss: -50.253787994384766, Critic Loss: 11.474825859069824
# Episode 7, Step 200, Total Reward: -5779.929492950439, Actor Loss: -1.0316631460227654e-06, Critic Loss: 74.87572479248047
# Episode 7, Step 300, Total Reward: -8095.594272613525, Actor Loss: -2.803351662805653e-06, Critic Loss: 0.5933061242103577
# Episode 7, Step 400, Total Reward: -15954.587673187256, Actor Loss: -2622.9814453125, Critic Loss: 27069.728515625
# Episode 7, Step 500, Total Reward: -23273.01641845703, Actor Loss: 2.080904550894047e-06, Critic Loss: 304.78204345703125
# Episode 7, Step 600, Total Reward: -27193.707916259766, Actor Loss: 8.267160415649414, Critic Loss: 732.7357177734375
# Episode 7, Step 700, Total Reward: -29714.279361724854, Actor Loss: -3.920837571058655e-06, Critic Loss: 1081.488037109375
# Episode 7, Step 800, Total Reward: -32722.990798950195, Actor Loss: -390.8764343261719, Critic Loss: 601.1355590820312
# Episode 7, Step 900, Total Reward: -36378.79369354248, Actor Loss: -83.51431274414062, Critic Loss: 32.751590728759766
# Episode 7, Step 1000, Total Reward: -39742.036628723145, Actor Loss: 16.67603302001953, Critic Loss: 785.4772338867188
# Episode 7, Step 1100, Total Reward: -43740.60800933838, Actor Loss: -573.4315185546875, Critic Loss: 1293.7685546875
# Episode 7, Step 1200, Total Reward: -46915.0765914917, Actor Loss: 23.96788215637207, Critic Loss: 641.1676635742188
# Episode 7, Step 1300, Total Reward: -52184.12239074707, Actor Loss: -1125.1446533203125, Critic Loss: 4980.92724609375
# Episode 7, Step 1400, Total Reward: -60375.551166534424, Actor Loss: -1355.1416015625, Critic Loss: 7225.4150390625
# Episode 7, Step 1500, Total Reward: -64464.382678985596, Actor Loss: -1.5561035979771987e-06, Critic Loss: 170.3675079345703
# Episode 7, Step 1600, Total Reward: -65414.85130691528, Actor Loss: -37.80018997192383, Critic Loss: 23.956436157226562
# Episode 7, Step 1700, Total Reward: -67375.25419998169, Actor Loss: 26.135540008544922, Critic Loss: 196.67050170898438
# Episode 7, Step 1800, Total Reward: -70197.4141998291, Actor Loss: -854.096923828125, Critic Loss: 2870.170654296875
# Episode 7, Step 1900, Total Reward: -74494.98556900024, Actor Loss: -723.1210327148438, Critic Loss: 2057.38427734375
# Episode 7, Step 2000, Total Reward: -81650.08843803406, Actor Loss: -790.8528442382812, Critic Loss: 2460.847900390625
# Episode 7, Step 2100, Total Reward: -89832.08848381042, Actor Loss: -985.1778564453125, Critic Loss: 3818.76318359375
# Episode 7, Step 2200, Total Reward: -96165.08850479126, Actor Loss: 3.496610641479492, Critic Loss: 0.05345398187637329
# Episode 7, Step 2300, Total Reward: -100152.08856201172, Actor Loss: 20.88724136352539, Critic Loss: 49.83753204345703
# Episode 7, Step 2400, Total Reward: -101193.08856964111, Actor Loss: 14.640037536621094, Critic Loss: 364.7018127441406
# Episode 7, Step 2500, Total Reward: -102957.08854103088, Actor Loss: 53.80389404296875, Critic Loss: 64.84259796142578
# Episode 7, Step 2600, Total Reward: -109458.08856964111, Actor Loss: -1026.8670654296875, Critic Loss: 4148.7939453125
# Episode 7, Step 2700, Total Reward: -116352.08860015869, Actor Loss: -893.007080078125, Critic Loss: 3137.640869140625
# Episode 7, Step 2800, Total Reward: -120297.0885848999, Actor Loss: -10.293766021728516, Critic Loss: 2.1479134559631348
# Episode 7, Step 2900, Total Reward: -126987.08860397339, Actor Loss: 2.8773183657904156e-06, Critic Loss: 582.6283569335938
# Episode 7, Step 3000, Total Reward: -130518.08869171143, Actor Loss: -860.24267578125, Critic Loss: 2911.624755859375
# Episode 7, Step 3100, Total Reward: -139167.08869171143, Actor Loss: 1.3268552478962192e-08, Critic Loss: 0.012612342834472656
# Episode 7, Step 3200, Total Reward: -144252.08873939514, Actor Loss: -5.103534022055101e-06, Critic Loss: 1832.742919921875
# Episode 7, Step 3300, Total Reward: -152415.08873939514, Actor Loss: -552.32421875, Critic Loss: 1200.27734375
# Episode 7, Step 3400, Total Reward: -158820.08876800537, Actor Loss: 306.66717529296875, Critic Loss: 687.4740600585938
# Episode 7, Step 3500, Total Reward: -160266.0888824463, Actor Loss: 21.716693878173828, Critic Loss: 1075.44287109375
# Episode 7, Step 3600, Total Reward: -164634.08894348145, Actor Loss: -240.1088104248047, Critic Loss: 226.83477783203125
# Episode 7, Step 3700, Total Reward: -171516.0890598297, Actor Loss: 135.1910400390625, Critic Loss: 121.52693939208984
# Episode 7, Step 3800, Total Reward: -178272.08907699585, Actor Loss: -491.87860107421875, Critic Loss: 951.939453125
# Episode 7, Step 3900, Total Reward: -187221.08907699585, Actor Loss: -426.7312316894531, Critic Loss: 716.4771118164062
# Episode 7, Step 4000, Total Reward: -196380.08907699585, Actor Loss: -577.8180541992188, Critic Loss: 1313.6376953125
# Episode 7, Step 4100, Total Reward: -203832.089094162, Actor Loss: 494.6109313964844, Critic Loss: 962.5445556640625
# Episode 7, Step 4200, Total Reward: -207372.08902740479, Actor Loss: 81.07462310791016, Critic Loss: 3889.4833984375
# Episode 7, Step 4300, Total Reward: -217527.0890197754, Actor Loss: 0.003007183549925685, Critic Loss: 1020.2222290039062
# Episode 7, Step 4400, Total Reward: -226272.0890197754, Actor Loss: -83.29273223876953, Critic Loss: 27.29654312133789
# Episode 7, Step 4500, Total Reward: -228861.08902740479, Actor Loss: 122.75361633300781, Critic Loss: 2050.17041015625
# Episode 7, Step 4600, Total Reward: -231897.08902740479, Actor Loss: 3.5419473078945884e-06, Critic Loss: 882.9138793945312
# Episode 7, Step 4700, Total Reward: -235632.08910751343, Actor Loss: 87.65786743164062, Critic Loss: 142.59718322753906
# Episode 7, Step 4800, Total Reward: -240819.08914375305, Actor Loss: -1099.320068359375, Critic Loss: 4754.90380859375
# Episode 7, Step 4900, Total Reward: -250740.08912849426, Actor Loss: -2.44882443212191e-07, Critic Loss: 4.215723037719727
# Episode 7, Step 5000, Total Reward: -256170.08912849426, Actor Loss: 90.48648834228516, Critic Loss: 414.9018859863281
# Episode 8, Step 100, Total Reward: -4613.746648788452, Actor Loss: 0.04960493743419647, Critic Loss: 745.865966796875
# Episode 8, Step 200, Total Reward: -7682.986627578735, Actor Loss: 2.45436021941714e-05, Critic Loss: 54.279048919677734
# Episode 8, Step 300, Total Reward: -12827.733450889587, Actor Loss: -5.117354362482729e-07, Critic Loss: 18.41910171508789
# Episode 8, Step 400, Total Reward: -17694.29353618622, Actor Loss: 118.75395965576172, Critic Loss: 134.02471923828125
# Episode 8, Step 500, Total Reward: -20845.680143356323, Actor Loss: -98.8465347290039, Critic Loss: 39.84765625
# Episode 8, Step 600, Total Reward: -22772.46010017395, Actor Loss: 4.162649631500244, Critic Loss: 18.53033447265625
# Episode 8, Step 700, Total Reward: -25216.133401870728, Actor Loss: -46.27426528930664, Critic Loss: 18.639793395996094
# Episode 8, Step 800, Total Reward: -27594.56005859375, Actor Loss: 11.189979553222656, Critic Loss: 16.508865356445312
# Episode 8, Step 900, Total Reward: -31966.999975204468, Actor Loss: -42.29849624633789, Critic Loss: 934.6634521484375
# Episode 8, Step 1000, Total Reward: -38044.199840545654, Actor Loss: -1.7099984006563318e-06, Critic Loss: 205.7361602783203
# Episode 8, Step 1100, Total Reward: -47041.99969291687, Actor Loss: -567.2156982421875, Critic Loss: 1265.8724365234375
# Episode 8, Step 1200, Total Reward: -52915.999616622925, Actor Loss: -395.8350830078125, Critic Loss: 616.4843139648438
# Episode 8, Step 1300, Total Reward: -57790.999614715576, Actor Loss: 86.07672882080078, Critic Loss: 552.077880859375
# Episode 8, Step 1400, Total Reward: -59638.99962234497, Actor Loss: 1.0445314645767212, Critic Loss: 257.5492248535156
# Episode 8, Step 1500, Total Reward: -63793.99954986572, Actor Loss: -2.355471679038601e-06, Critic Loss: 390.38079833984375
# Episode 8, Step 1600, Total Reward: -69175.99954986572, Actor Loss: -744.2944946289062, Critic Loss: 2179.631591796875
# Episode 8, Step 1700, Total Reward: -73063.99962425232, Actor Loss: -240.8522186279297, Critic Loss: 228.2415771484375
# Episode 8, Step 1800, Total Reward: -77014.99963378906, Actor Loss: -234.55856323242188, Critic Loss: 216.46914672851562
# Episode 8, Step 1900, Total Reward: -78796.99969482422, Actor Loss: 16.7868595123291, Critic Loss: 14.896659851074219
# Episode 8, Step 2000, Total Reward: -85237.99973106384, Actor Loss: -857.3663330078125, Critic Loss: 2892.1865234375
# Episode 8, Step 2100, Total Reward: -93586.99976348877, Actor Loss: -356.30218505859375, Critic Loss: 499.494140625
# Episode 8, Step 2200, Total Reward: -100525.99991226196, Actor Loss: -275.2630310058594, Critic Loss: 298.1186828613281
# Episode 8, Step 2300, Total Reward: -104590.99991989136, Actor Loss: -411.86309814453125, Critic Loss: 667.4199829101562
# Episode 8, Step 2400, Total Reward: -107980.99984741211, Actor Loss: -9.723144466988742e-05, Critic Loss: 27.917394638061523
# Episode 8, Step 2500, Total Reward: -110308.99987220764, Actor Loss: 34.267704010009766, Critic Loss: 233.02439880371094
# Episode 8, Step 2600, Total Reward: -114298.99979782104, Actor Loss: 1.3797025530948304e-05, Critic Loss: 536.5737915039062
# Episode 8, Step 2700, Total Reward: -118636.99978256226, Actor Loss: -285.5422668457031, Critic Loss: 320.7999267578125
# Episode 8, Step 2800, Total Reward: -125410.99981117249, Actor Loss: -81.2808837890625, Critic Loss: 457.9871826171875
# Episode 8, Step 2900, Total Reward: -128182.999792099, Actor Loss: 69.02960968017578, Critic Loss: 323.0426940917969
# Episode 8, Step 3000, Total Reward: -138088.9997806549, Actor Loss: -2244.30322265625, Critic Loss: 19817.84765625
# Episode 8, Step 3100, Total Reward: -147673.9997806549, Actor Loss: -1129.714111328125, Critic Loss: 5021.46630859375
# Episode 8, Step 3200, Total Reward: -157387.9997806549, Actor Loss: 2.390178451605607e-06, Critic Loss: 402.05340576171875
# Episode 8, Step 3300, Total Reward: -161815.9997806549, Actor Loss: 0.002274793339893222, Critic Loss: 203.048583984375
# Episode 8, Step 3400, Total Reward: -165259.99981880188, Actor Loss: -2.5401559469173662e-06, Critic Loss: 454.004150390625
# Episode 8, Step 3500, Total Reward: -169675.99987220764, Actor Loss: 13.549266815185547, Critic Loss: 388.39593505859375
# Episode 8, Step 3600, Total Reward: -176863.99989891052, Actor Loss: -430.1952819824219, Critic Loss: 728.156494140625
# Episode 8, Step 3700, Total Reward: -180844.99996566772, Actor Loss: 25.274490356445312, Critic Loss: 1025.6568603515625
# Episode 8, Step 3800, Total Reward: -183005.0000667572, Actor Loss: 3.752856731414795, Critic Loss: 0.4629712700843811
# Episode 8, Step 3900, Total Reward: -185816.00003433228, Actor Loss: 0.00032895468757487833, Critic Loss: 108.26971435546875
# Episode 8, Step 4000, Total Reward: -187358.0001220703, Actor Loss: 20.080411911010742, Critic Loss: 377.79742431640625
# Episode 8, Step 4100, Total Reward: -189233.0001564026, Actor Loss: 24.554611206054688, Critic Loss: 262.4858703613281
# Episode 8, Step 4200, Total Reward: -193439.00022506714, Actor Loss: -439.49761962890625, Critic Loss: 759.9874877929688
# Episode 8, Step 4300, Total Reward: -199262.00026130676, Actor Loss: -93.24504852294922, Critic Loss: 34.2093620300293
# Episode 8, Step 4400, Total Reward: -205103.00039100647, Actor Loss: -1159.037841796875, Critic Loss: 5285.53125
# Episode 8, Step 4500, Total Reward: -210932.0004386902, Actor Loss: 17.299415588378906, Critic Loss: 291.6123352050781
# Episode 8, Step 4600, Total Reward: -215465.00036239624, Actor Loss: 3.5209582165407483e-06, Critic Loss: 218.70193481445312
# Episode 8, Step 4700, Total Reward: -218642.0003566742, Actor Loss: 40.61027145385742, Critic Loss: 67.23519897460938
# Episode 8, Step 4800, Total Reward: -223166.00040245056, Actor Loss: -8.328233525389805e-05, Critic Loss: 38.40610122680664
# Episode 8, Step 4900, Total Reward: -224747.00036621094, Actor Loss: 1.1847165822982788, Critic Loss: 463.15325927734375
# Episode 8, Step 5000, Total Reward: -227786.00039100647, Actor Loss: 3.437182158450014e-06, Critic Loss: 832.0886840820312
# Episode 9, Step 100, Total Reward: -4701.813116073608, Actor Loss: 0.002201259136199951, Critic Loss: 1722.736328125
# ...
# Episode 498, Step 2900, Total Reward: -40042.8883895874, Actor Loss: 8.10262257289196e-09, Critic Loss: 0.004756823182106018
# Episode 498, Step 3000, Total Reward: -41397.69975948334, Actor Loss: -4.527856276581588e-07, Critic Loss: 14.41904067993164
# Episode 498, Step 3100, Total Reward: -42754.555565834045, Actor Loss: 1.9326107381090196e-09, Critic Loss: 0.00029624998569488525
# Episode 498, Step 3200, Total Reward: -44118.38470363617, Actor Loss: -5.703186811700789e-10, Critic Loss: 1.4320015907287598e-05
# Episode 498, Step 3300, Total Reward: -45435.73384952545, Actor Loss: -8.43047046661377, Critic Loss: 0.27963852882385254
# Episode 498, Step 3400, Total Reward: -46856.174105644226, Actor Loss: -1.647160408069226e-09, Critic Loss: 0.0001642853021621704
# Episode 498, Step 3500, Total Reward: -48274.10993862152, Actor Loss: 1.1740601379983673e-08, Critic Loss: 0.00989772379398346
# Episode 498, Step 3600, Total Reward: -49608.31018733978, Actor Loss: -7.555354952781812e-11, Critic Loss: 1.341104507446289e-07
# Episode 498, Step 3700, Total Reward: -51032.008246421814, Actor Loss: 2.0093283981115206e-10, Critic Loss: 7.212162017822266e-06
# Episode 498, Step 3800, Total Reward: -52360.061836242676, Actor Loss: 3.0670409202575684, Critic Loss: 0.037011146545410156
# Episode 498, Step 3900, Total Reward: -53742.917642593384, Actor Loss: -4.601052410180273e-07, Critic Loss: 14.88912296295166
# Episode 498, Step 4000, Total Reward: -55101.70234680176, Actor Loss: -4.5178154550740146e-07, Critic Loss: 14.355144500732422
# Episode 498, Step 4100, Total Reward: -56494.587054252625, Actor Loss: -6.522052231616726e-09, Critic Loss: 0.0028848648071289062
# Episode 498, Step 4200, Total Reward: -57829.5184173584, Actor Loss: 2.445885716184648e-10, Critic Loss: 9.313225746154785e-06
# Episode 498, Step 4300, Total Reward: -59179.86756324768, Actor Loss: 1.7143312325273996e-09, Critic Loss: 0.0002365708351135254
# Episode 498, Step 4400, Total Reward: -60524.216711997986, Actor Loss: 2.776621821354297e-09, Critic Loss: 0.000590100884437561
# Episode 498, Step 4500, Total Reward: -62000.55474567413, Actor Loss: 1.4505465273373375e-08, Critic Loss: 0.015050545334815979
# Episode 498, Step 4600, Total Reward: -63355.608410835266, Actor Loss: -1.6762642385259596e-09, Critic Loss: 0.00017060339450836182
# Episode 498, Step 4700, Total Reward: -64732.22207355499, Actor Loss: -58.95880126953125, Critic Loss: 13.676995277404785
# Episode 498, Step 4800, Total Reward: -66119.426861763, Actor Loss: 4.774192152723344e-10, Critic Loss: 2.504885196685791e-05
# Episode 498, Step 4900, Total Reward: -67454.35830402374, Actor Loss: -1.2979144425884215e-09, Critic Loss: 9.776651859283447e-05
# Episode 498, Step 5000, Total Reward: -68814.45640277863, Actor Loss: 2.9803406409456557e-09, Critic Loss: 0.0006760507822036743
# Episode 499, Step 100, Total Reward: -1596.9744873046875, Actor Loss: -3.52435747252855e-09, Critic Loss: 0.0008159279823303223
# Episode 499, Step 200, Total Reward: -3143.163263320923, Actor Loss: -6.285347797785334e-10, Critic Loss: 1.825392246246338e-05
# Episode 499, Step 300, Total Reward: -4695.174894332886, Actor Loss: 8.848001220584933e-10, Critic Loss: 7.094442844390869e-05
# Episode 499, Step 400, Total Reward: -6233.020817756653, Actor Loss: -1.7345888614350713e-11, Critic Loss: 7.301568984985352e-07
# Episode 499, Step 500, Total Reward: -7802.515303611755, Actor Loss: -8.177012400523154e-10, Critic Loss: 3.4332275390625e-05
# Episode 499, Step 600, Total Reward: -9363.66693687439, Actor Loss: 1.1362134844095095e-10, Critic Loss: 3.814697265625e-06
# Episode 499, Step 700, Total Reward: -10916.638564109802, Actor Loss: -1.3785846419978043e-07, Critic Loss: 1.3349387645721436
# Episode 499, Step 800, Total Reward: -12515.544478416443, Actor Loss: -68.43431854248047, Critic Loss: 18.426437377929688
# Episode 499, Step 900, Total Reward: -14023.567538261414, Actor Loss: 5.356268761858018e-10, Critic Loss: 3.0174851417541504e-05
# Episode 499, Step 1000, Total Reward: -15561.404887199402, Actor Loss: 3.664288650284675e-09, Critic Loss: 0.0010073184967041016
# Episode 499, Step 1100, Total Reward: -17117.790811538696, Actor Loss: -79.50952911376953, Critic Loss: 24.873207092285156
# Episode 499, Step 1200, Total Reward: -18660.796730041504, Actor Loss: -2.5017654614600815e-10, Critic Loss: 1.2069940567016602e-06
# Episode 499, Step 1300, Total Reward: -20203.49693775177, Actor Loss: 2.863933312724498e-09, Critic Loss: 0.0006262212991714478
# Episode 499, Step 1400, Total Reward: -21762.419995307922, Actor Loss: -7.189547091002169e-07, Critic Loss: 36.36125183105469
# Episode 499, Step 1500, Total Reward: -23354.951632499695, Actor Loss: 8.703209264382394e-10, Critic Loss: 6.890296936035156e-05
# Episode 499, Step 1600, Total Reward: -24939.408975601196, Actor Loss: 5.0758246494808645e-09, Critic Loss: 0.00189913809299469
# Episode 499, Step 1700, Total Reward: -26549.500599861145, Actor Loss: 6.836606392113254e-09, Critic Loss: 0.003404676914215088
# Episode 499, Step 1800, Total Reward: -28093.16937828064, Actor Loss: 6.811460284694704e-10, Critic Loss: 4.507601261138916e-05
# Episode 499, Step 1900, Total Reward: -29664.603863716125, Actor Loss: -3.1897803842717565e-11, Critic Loss: 5.364418029785156e-07
# Episode 499, Step 2000, Total Reward: -31246.589774131775, Actor Loss: -4.848581536265328e-09, Critic Loss: 0.0015739351511001587
# Episode 499, Step 2100, Total Reward: -32870.54996871948, Actor Loss: 1.5397090269431146e-09, Critic Loss: 0.00019365549087524414
# Episode 499, Step 2200, Total Reward: -34467.51016712189, Actor Loss: -76.9504165649414, Critic Loss: 23.297826766967773
# Episode 499, Step 2300, Total Reward: -35982.527512550354, Actor Loss: -3.3748803751620926e-10, Critic Loss: 3.3527612686157227e-06
# Episode 499, Step 2400, Total Reward: -37506.38486480713, Actor Loss: -5.703758576558471e-10, Critic Loss: 1.4320015907287598e-05
# Episode 499, Step 2500, Total Reward: -39037.43078804016, Actor Loss: 5.501787914141687e-10, Critic Loss: 3.153085708618164e-05
# Episode 499, Step 2600, Total Reward: -40585.945276260376, Actor Loss: 6.22938367556003e-10, Critic Loss: 3.8757920265197754e-05
# Episode 499, Step 2700, Total Reward: -42128.63690948486, Actor Loss: 4.337634695872339e-10, Critic Loss: 2.1517276763916016e-05
# Episode 499, Step 2800, Total Reward: -43693.47997093201, Actor Loss: 6.662021490022596e-10, Critic Loss: 4.3451786041259766e-05
# Episode 499, Step 2900, Total Reward: -45255.983030319214, Actor Loss: 2.1363375513061555e-09, Critic Loss: 0.00035800039768218994
# Episode 499, Step 3000, Total Reward: -46752.474665641785, Actor Loss: -29.2867374420166, Critic Loss: 3.374701738357544
# Episode 499, Step 3100, Total Reward: -48359.826296806335, Actor Loss: 6.811460284694704e-10, Critic Loss: 4.507601261138916e-05
# Episode 499, Step 3200, Total Reward: -49957.93792057037, Actor Loss: -1.1087395446196524e-09, Critic Loss: 6.890296936035156e-05
# Episode 499, Step 3300, Total Reward: -51520.44097995758, Actor Loss: 2.0490260599359544e-09, Critic Loss: 0.0003308206796646118
# Episode 499, Step 3400, Total Reward: -53102.761180877686, Actor Loss: 5.803419966809997e-09, Critic Loss: 0.0024683624505996704
# Episode 499, Step 3500, Total Reward: -54703.432812690735, Actor Loss: -72.73518371582031, Critic Loss: 20.815292358398438
# Episode 499, Step 3600, Total Reward: -56234.77873134613, Actor Loss: 4.4937480403461905e-09, Critic Loss: 0.0014974027872085571
# Episode 499, Step 3700, Total Reward: -57788.07321929932, Actor Loss: -8.638701438903809, Critic Loss: 0.2936232089996338
# Episode 499, Step 3800, Total Reward: -59375.71341896057, Actor Loss: 1.0303919939502748e-09, Critic Loss: 9.299814701080322e-05
# Episode 499, Step 3900, Total Reward: -60936.865052223206, Actor Loss: 4.0861772299116694e-11, Critic Loss: 1.8030405044555664e-06
# Episode 499, Step 4000, Total Reward: -62494.51954269409, Actor Loss: -6.430782573119131e-10, Critic Loss: 1.9311904907226562e-05
# Episode 499, Step 4100, Total Reward: -64002.551177978516, Actor Loss: -1.5237900018692017, Critic Loss: 0.009135738015174866
# Episode 499, Step 4200, Total Reward: -65546.02567100525, Actor Loss: -1.2124152183532715, Critic Loss: 0.005783572793006897
# Episode 499, Step 4300, Total Reward: -67142.00872325897, Actor Loss: -3.146403315668067e-08, Critic Loss: 0.06913715600967407
# Episode 499, Step 4400, Total Reward: -68708.02035617828, Actor Loss: 9.285285873517068e-10, Critic Loss: 7.724761962890625e-05
# Episode 499, Step 4500, Total Reward: -70246.06056499481, Actor Loss: -2.356246309176413e-10, Critic Loss: 9.5367431640625e-07
# Episode 499, Step 4600, Total Reward: -71784.09219932556, Actor Loss: 2.878485227952865e-09, Critic Loss: 0.0006323456764221191
# Episode 499, Step 4700, Total Reward: -73340.37525844574, Actor Loss: 1.8161954162820848e-09, Critic Loss: 0.0002635866403579712
# Episode 499, Step 4800, Total Reward: -74892.19260406494, Actor Loss: 6.99656027558504e-11, Critic Loss: 2.518296241760254e-06
# Episode 499, Step 4900, Total Reward: -76430.23281288147, Actor Loss: 9.867362482651743e-10, Critic Loss: 8.606910705566406e-05
# Episode 499, Step 5000, Total Reward: -77951.07301425934, Actor Loss: -12.83447551727295, Critic Loss: 0.6481114625930786
# Episode 500, Step 100, Total Reward: -1900.0645141601562, Actor Loss: -2.54938092858481e-09, Critic Loss: 0.0004155784845352173
# Episode 500, Step 200, Total Reward: -3710.090133666992, Actor Loss: -1.2241194724538218e-08, Critic Loss: 0.010339751839637756
# Episode 500, Step 300, Total Reward: -5455.594650268555, Actor Loss: 2.223506045950785e-09, Critic Loss: 0.0003862529993057251
# Episode 500, Step 400, Total Reward: -7229.601379394531, Actor Loss: 1.4523968694390987e-09, Critic Loss: 0.00017380714416503906
# Episode 500, Step 500, Total Reward: -8979.70588684082, Actor Loss: -4.2347807038822793e-07, Critic Loss: 12.612381935119629
# Episode 500, Step 600, Total Reward: -10699.550399780273, Actor Loss: 3.574663010041945e-09, Critic Loss: 0.0009613633155822754
# Episode 500, Step 700, Total Reward: -12398.734909057617, Actor Loss: -19.089216232299805, Critic Loss: 1.4337372779846191
# Episode 500, Step 800, Total Reward: -14137.699417114258, Actor Loss: 5.5413243438273696e-11, Critic Loss: 2.1457672119140625e-06
# Episode 500, Step 900, Total Reward: -15903.983917236328, Actor Loss: 1.0649197079715123e-08, Critic Loss: 0.008159875869750977
# Episode 500, Step 1000, Total Reward: -17627.94842529297, Actor Loss: 1.1757803064504913e-11, Critic Loss: 1.2069940567016602e-06
# Episode 500, Step 1100, Total Reward: -19401.037384033203, Actor Loss: -6.661472320556641, Critic Loss: 0.17459584772586823
# Episode 500, Step 1200, Total Reward: -20990.661895751953, Actor Loss: 7.816071123656343e-10, Critic Loss: 5.728006362915039e-05
# Episode 500, Step 1300, Total Reward: -22610.286407470703, Actor Loss: -6.444488831469641e-10, Critic Loss: 1.9311904907226562e-05
# Episode 500, Step 1400, Total Reward: -24286.75425720215, Actor Loss: -2.200139403996104e-09, Critic Loss: 0.0003047138452529907
# Episode 500, Step 1500, Total Reward: -25911.158767700195, Actor Loss: -4.93482499308584e-09, Critic Loss: 0.0016129165887832642
# Episode 500, Step 1600, Total Reward: -27536.22328186035, Actor Loss: -9.691535352018832e-10, Critic Loss: 5.0127506256103516e-05
# Episode 500, Step 1700, Total Reward: -29189.530014038086, Actor Loss: 9.256846955629783e-10, Critic Loss: 7.724761962890625e-05
# Episode 500, Step 1800, Total Reward: -30846.474517822266, Actor Loss: 2.7601695151702188e-08, Critic Loss: 0.05407668650150299
# Episode 500, Step 1900, Total Reward: -32491.759033203125, Actor Loss: 9.721843330368074e-10, Critic Loss: 8.381903171539307e-05
# Episode 500, Step 2000, Total Reward: -34086.60354614258, Actor Loss: -14.75332260131836, Critic Loss: 0.8563929796218872
# Episode 500, Step 2100, Total Reward: -35760.12805175781, Actor Loss: 1.7288752651722916e-09, Critic Loss: 0.00024034082889556885
# Episode 500, Step 2200, Total Reward: -37418.253662109375, Actor Loss: 2.6243616169097095e-09, Critic Loss: 0.0005322843790054321
# Episode 500, Step 2300, Total Reward: -39062.95927429199, Actor Loss: 6.53101572822834e-09, Critic Loss: 0.003112092614173889
# Episode 500, Step 2400, Total Reward: -40733.72378540039, Actor Loss: -1.7446026845391316e-09, Critic Loss: 0.00018030405044555664
# Episode 500, Step 2500, Total Reward: -42354.268295288086, Actor Loss: -26.02313995361328, Critic Loss: 2.664482355117798
# Episode 500, Step 2600, Total Reward: -44004.552810668945, Actor Loss: -1.6286505477580704e-10, Critic Loss: 1.341104507446289e-07
# Episode 500, Step 2700, Total Reward: -45676.6784362793, Actor Loss: -7.751564945479572e-10, Critic Loss: 2.384185791015625e-05
# Episode 500, Step 2800, Total Reward: -47350.68516540527, Actor Loss: -4.515737783705731e-10, Critic Loss: 4.306435585021973e-06
# Episode 500, Step 2900, Total Reward: -48985.30967712402, Actor Loss: 1.642326497020008e-09, Critic Loss: 0.00022912025451660156
# Episode 500, Step 3000, Total Reward: -50691.95751953125, Actor Loss: -1.2979177732574954e-09, Critic Loss: 9.776651859283447e-05
# Episode 500, Step 3100, Total Reward: -52327.76313781738, Actor Loss: -1.459366960609998e-09, Critic Loss: 0.00012612342834472656
# Episode 500, Step 3200, Total Reward: -53991.72987365723, Actor Loss: 9.721834448583877e-10, Critic Loss: 8.381903171539307e-05
# Episode 500, Step 3300, Total Reward: -55628.0177154541, Actor Loss: -2.1932456493377686, Critic Loss: 0.01892639696598053
# Episode 500, Step 3400, Total Reward: -57333.30223083496, Actor Loss: -3.2413214512416744e-07, Critic Loss: 7.387619495391846
# Episode 500, Step 3500, Total Reward: -58998.146743774414, Actor Loss: 6.18273401260376, Critic Loss: 0.15040232241153717
# Episode 500, Step 3600, Total Reward: -60577.771255493164, Actor Loss: -13.03881549835205, Critic Loss: 0.6689131259918213
# Episode 500, Step 3700, Total Reward: -62269.896881103516, Actor Loss: -2.2293307200271784e-09, Critic Loss: 0.00031329691410064697
# Episode 500, Step 3800, Total Reward: -63919.08139038086, Actor Loss: 11.378799438476562, Critic Loss: 0.5094320774078369
# Episode 500, Step 3900, Total Reward: -65534.145904541016, Actor Loss: -1.6772838673517754e-09, Critic Loss: 0.00017060339450836182
# Episode 500, Step 4000, Total Reward: -67323.47708129883, Actor Loss: -15.185355186462402, Critic Loss: 0.907284140586853
# Episode 500, Step 4100, Total Reward: -69008.28715515137, Actor Loss: -1.7788435116017354e-06, Critic Loss: 222.63685607910156
# Episode 500, Step 4200, Total Reward: -70715.41278076172, Actor Loss: -2.0652750343241877e-10, Critic Loss: 5.364418029785156e-07
# Episode 500, Step 4300, Total Reward: -72360.69729614258, Actor Loss: 1.1177031522535685e-09, Critic Loss: 0.00010766088962554932
# Episode 500, Step 4400, Total Reward: -73975.54180908203, Actor Loss: -9.777725296089557e-10, Critic Loss: 5.187094211578369e-05
# Episode 500, Step 4500, Total Reward: -75695.46853637695, Actor Loss: 0.5371213555335999, Critic Loss: 0.001135110855102539
# Episode 500, Step 4600, Total Reward: -77347.89414978027, Actor Loss: -7.303897486821143e-10, Critic Loss: 2.6285648345947266e-05
# Episode 500, Step 4700, Total Reward: -78977.07865905762, Actor Loss: -3.520427283021377e-10, Critic Loss: 3.814697265625e-06
# Episode 500, Step 4800, Total Reward: -80611.48316955566, Actor Loss: 2.631101336802999e-09, Critic Loss: 0.0005322843790054321
# Episode 500, Step 4900, Total Reward: -82269.30879211426, Actor Loss: 9.99310190152869e-10, Critic Loss: 8.834898471832275e-05
# Episode 500, Step 5000, Total Reward: -83901.69441223145, Actor Loss: -1.5338785797069932e-09, Critic Loss: 1.4320015907287598e-05
# Training complete!
# Total reward on test set: -79904.85631942749
# Analysis of energy consumption before and after applying RL:
# Average energy consumption before RL: 98.02 Wh
# Average energy consumption after RL (estimated): 117.63 Wh
# Estimated energy savings: -20.00%
# Reinforcement learning process completed.

# %% [markdown]
# #### Observations
#
# - We have purposelly taken small step size (200) for increasing iteration speed per episode.
